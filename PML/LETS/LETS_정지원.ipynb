# %% [markdown]
# # LETS
#
# - 발표자 : 정지원
# - 발표일 : 2017년 1월 26일(목)
#
# -------------------------
# ## [  목 차  ]
# 1. 인공지능이란?
# 2. 머신러닝/딥러닝
# 3. 인공지능의 활용
# 4. 다가올 미래

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # 1. 인공지능이란?
#
#
# 당신이 생각하는 인공지능이란?
#
# ![Image](figures/1.png)
#
# 1956년, 처음으로 인공지능이라는 분야가 생기다.
#
# ![Image](figures/2.png)
#
# 제 2차 세계대전에서 컴퓨터가 탄생하면서 컴퓨터의 논리를 응용해보려는 많은 시도가 있었다.
#
# 지능의 특성을 정교하게 기계로 시뮬레이션 할 수 있을까?
#
# ### 미적분좀 풀어주세요.
#
# ![Image](figures/6.png)
#
# ### 울프람알파 - 인공지능 엔진
#
# ![Image](figures/5.png)
#
#
# ### 컴퓨터는 금융/미적분학/공학에서 우리보다 훨씬 뛰어나다.
#
# ### 사람에게 쉬운 일을 컴퓨터가 할 수 있을까?
#
# ![Image](figures/4.png)
#
# ![Image](figures/3.png)
#
# ### 인간에게 쉬운 일이 컴퓨터에게는 어렵다.
#
# ### 쉬운 일??
#
# - 부모님의 얼굴을 알아보는 일
# - 걸어다니는 일, 손으로 물건을 잡는 일
# - 친구가 하는 말을 듣고 알아듣는 일
#
# ![Image](figures/7.png)

# %% [markdown]
# ----------------------
#
# # 2. 머신러닝/딥러닝
#
# ## 인공신경망
#
# ![Image](figures/10.png)
#
# ![Image](figures/11.png)
#
#
# ## __머신러닝이란?__
#
# - 1959년 개념이 처음 등장
# - 수십년간 별다른 발전이 없었음
# - 알고리즘의 문제가 많아서 인기가 없었음(과적합/Vanishing)
# - 2000년대 중반부터 많은 발전이 이루어짐
# - 많은 연구를 통해 주목받기 시작
#
# ![Image](figures/8.png)
#
# > 과거의 인공지능
# >> 기호적인 인공지능(Symbolic AI)
#
# >> 규칙기반 인공지능(Rule-based AI)
#
# > 현재의 인공지능
# >> 기계학습(Machine Learning)
# >>> 지도 학습(Supervised Learning)
#
# >>> 비지도 학습(Unsupervised Learning)
#
# >>> 강화 학습(Reinforcement Learning)
#
# >> 딥 러닝(Deep Learning)
# >>> Convolutional Neural Network
#
# >>> Recurrent Neural Network
#
# >>> ...
#
#
#
# **딥러닝?**
#
# - 인공신경망 모델의 단점 극복
# - GPU 성능 발달
# - 히든레이어 수의 증가
# - 특징을 알아서 추출하여 학습
#
# ![Image](figures/12.png)

# %% [markdown]
# ---------------------
#
# # 3. 인공지능의 활용
#
# ## 구글 번역기(A rnasterpiece)
#
# ![Image](figures/13.png)
# ![Image](figures/13_0.png)
#
# ## Amazon Echo(인공지능 비서/허브)
#
# ![Image](figures/13_1.png)
# ![Image](figures/14.png)
#
#
# ## ChatBot
#
# ![Image](figures/15.png)
# ![Image](figures/16.png)
#
#
# ## 퀴즈왕
#
# ![Image](figures/17.png)
# ![Image](figures/18.png)

# %% [markdown]
# ## 이미지 인식
#
# ![Image](figures/25.png)
# ![Image](figures/25_1.png)
# ![Image](figures/25_2.png)
#
#
# ## 인공지능 변호사
#
# ![Image](figures/21.png)
# ![Image](figures/22.png)
# ###### 죠슈아 브로더 - 16만명이 40~50억원의 주차위반벌금을 안 낼 수 있도록 도와준 19세 청년
#
# ## 주식
#
# ![Image](figures/23.png)
# ![Image](figures/24.png)
#
# ## 예술
#
# ![Image](figures/20.png)
# ![Image](figures/20_1.png)
# ![Image](figures/19.png)
#
# ## 게임

# %%
YouTubeVideo('qv6UVOQ0F44')

# %%
YouTubeVideo('exXD6wJLJ6s')

# %% [markdown]
# ## 큐브 맞추기(사람vs기계)

# %%
YouTubeVideo('0xJMS7LuKpI')

# %%
YouTubeVideo('NacrmfnJ-s0')

# %%
YouTubeVideo('by1yz7Toick')

# %% [markdown]
# # 4. 다가올 미래

# %% [markdown]
# ## 당신이 여기 서있다면 무슨 느낌이겠는가?
# ![Image](figures/26.png)
# ## 하지만 미래를 알 수 없으므로 실제론 이런 느낌일 것이다.
# ![Image](figures/26_1.png)
#
#
# ![Image](figures/27.gif)
#
# ![Image](figures/28.png)
# ![Image](figures/28_1.png)
