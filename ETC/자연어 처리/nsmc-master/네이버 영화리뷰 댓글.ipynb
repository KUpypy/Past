# %%
import konlpy
import gensim
from pprint import pprint

# %%
def read_data(filename):
    with open(filename, 'r') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        data = data[1:]   # header 제외
    return data
train_data = read_data('ratings_train.txt')
test_data = read_data('ratings_test.txt')

# %%
from konlpy.tag import Twitter
pos_tagger = Twitter()

# %%
pos_tagger.pos('나는 밥을 먹는다.')
# Out:
# [('나', 'Noun'),
#  ('는', 'Josa'),
#  ('밥', 'Noun'),
#  ('을', 'Josa'),
#  ('먹는', 'Verb'),
#  ('다', 'Eomi'),
#  ('.', 'Punctuation')]

# %%
def tokenize(doc):
    # norm, stem은 optional
    return ['/'.join(t) for t in pos_tagger.pos(doc, norm=True, stem=True)]

# %%
train_docs = [(tokenize(row[1]), row[2]) for row in train_data]
test_docs = [(tokenize(row[1]), row[2]) for row in test_data]

# %%
train_docs[0]
# Out:
# (['아/Exclamation',
#   '더빙/Noun',
#   '../Punctuation',
#   '진짜/Noun',
#   '짜증/Noun',
#   '나다/Verb',
#   '목소리/Noun'],
#  '0')

# %%
len(set(tokens))

48765개 columns
15만개 rows
# Out:
# 48765

# %%
len(tokens)
# Out:
# 2194536

# %%
tokens = [t for d in train_docs for t in d[0]]

# %%
import nltk
text = nltk.Text(tokens, name='NMSC')
print(text)
# Out:
# <Text: NMSC>

# %%
pprint(text.vocab().most_common(10))
# Out:
# [('./Punctuation', 68630),
#  ('영화/Noun', 51365),
#  ('하다/Verb', 50281),
#  ('이/Josa', 39123),
#  ('보다/Verb', 34764),
#  ('의/Josa', 30480),
#  ('../Punctuation', 29055),
#  ('에/Josa', 27108),
#  ('가/Josa', 26696),
#  ('을/Josa', 23481)]

# %%
selected_words = [f[0] for f in text.vocab().most_common(2000)]

def term_exists(doc):
    return {'exists({})'.format(word): (word in set(doc)) for word in selected_words}

# %%
term_exists(train_docs[0][0])
# Out:
# {'exists(아/Exclamation)': True,
#  'exists(일본/Noun)': False,
#  'exists(반개/Noun)': False,
#  'exists(저/Noun)': False,
#  'exists(이정/Noun)': False,
#  'exists(전문가/Noun)': False,
#  'exists(곳/Noun)': False,
#  'exists(이쁘다/Adjective)': False,
#  'exists(아무리/Adverb)': False,
#  'exists(^^/Punctuation)': False,
#  'exists(죽음/Noun)': False,
#  'exists(전쟁영화/Noun)': False,
#  'exists(~!/Punctuation)': False,
#  'exists(~^^/Punctuation)': False,
#  'exists(하지만/Conjunction)': False,
#  'exists(화면/Noun)': False,
#  'exists(먹다/Verb)': False,
#  'exists(커플/Noun)': False,
#  'exists(이름/Noun)': False,
#  'exists(짓다/Verb)': False,
#  'exists(버리다/Verb)': False,
#  'exists(굉장하다/Adjective)': False,
#  'exists(는걸/Noun)': False,
#  'exists(비디오/Noun)': False,
#  'exists(정서/Noun)': False,
#  'exists(내/Determiner)': False,
#  'exists(</Punctuation)': False,
#  'exists(이도/Noun)': False,
#  'exists(15/Number)': False,
#  'exists(거리/Noun)': False,
#  'exists(와/Josa)': False,
#  'exists(혼자/Noun)': False,
#  'exists(장난/Noun)': False,
#  'exists(척/Noun)': False,
#  'exists(예/Noun)': False,
#  'exists(은근/Noun)': False,
#  'exists(내리다/Verb)': False,
#  'exists(복수/Noun)': False,
#  'exists(이다/Josa)': False,
#  'exists(네/Determiner)': False,
#  'exists(그린/Noun)': False,
#  'exists(장/Noun)': False,
#  'exists(본인/Noun)': False,
#  'exists(베/Noun)': False,
#  'exists("""""""/Punctuation)': False,
#  'exists(뻔하다/Adjective)': False,
#  'exists(발연기/Noun)': False,
#  'exists(만나다/Verb)': False,
#  'exists(야/Exclamation)': False,
#  'exists(가수/Noun)': False,
#  'exists(빡치다/Adjective)': False,
#  'exists(D/Alpha)': False,
#  'exists(the/Alpha)': False,
#  'exists(스타일/Noun)': False,
#  'exists(귀엽다/Adjective)': False,
#  'exists(돌다/Verb)': False,
#  'exists(돌아가다/Verb)': False,
#  'exists(허다/Verb)': False,
#  'exists(만큼은/Josa)': False,
#  'exists(시청자/Noun)': False,
#  'exists(줌/Noun)': False,
#  'exists(짧다/Adjective)': False,
#  'exists(낳다/Verb)': False,
#  'exists(13/Number)': False,
#  'exists(색다르다/Adjective)': False,
#  'exists(함께/Adverb)': False,
#  'exists(정도/Noun)': False,
#  'exists(맞추다/Verb)': False,
#  'exists(지르다/Verb)': False,
#  'exists(뭐라다/Verb)': False,
#  'exists(니까/Josa)': False,
#  'exists(라이/Noun)': False,
#  'exists(어렵다/Adjective)': False,
#  'exists(애니메이션/Noun)': False,
#  'exists(으로서/Josa)': False,
#  'exists(그/Noun)': False,
#  'exists(50/Number)': False,
#  'exists(메세지/Noun)': False,
#  'exists(확인/Noun)': False,
#  'exists(공포/Noun)': False,
#  'exists(낚였/Noun)': False,
#  'exists(나르다/Verb)': False,
#  'exists(젠장/Noun)': False,
#  'exists(중간/Noun)': False,
#  'exists(가장/Noun)': False,
#  'exists(화가/Noun)': False,
#  'exists(뻔/Noun)': False,
#  'exists(적/Suffix)': False,
#  'exists(모자라다/Verb)': False,
#  'exists(뽑다/Verb)': False,
#  'exists(당신/Noun)': False,
#  'exists(계/Suffix)': False,
#  'exists(걸다/Verb)': False,
#  'exists(유머/Noun)': False,
#  'exists(각본/Noun)': False,
#  'exists([/Punctuation)': False,
#  'exists(더불다/Verb)': False,
#  'exists(엄청/Adverb)': False,
#  'exists(상미/Noun)': False,
#  'exists(정체/Noun)': False,
#  'exists(의외로/Adverb)': False,
#  'exists(......./Punctuation)': False,
#  'exists(허세/Noun)': False,
#  'exists(호러/Noun)': False,
#  'exists(분노/Noun)': False,
#  'exists(다루다/Verb)': False,
#  'exists(청소년/Noun)': False,
#  'exists(까지는/Josa)': False,
#  'exists(친구/Noun)': False,
#  'exists(류/Noun)': False,
#  'exists(살아나다/Verb)': False,
#  'exists(뜨겁다/Adjective)': False,
#  'exists(그리고/Conjunction)': False,
#  'exists(잔잔/Noun)': False,
#  'exists(여성/Noun)': False,
#  'exists(노출/Noun)': False,
#  'exists(차/Noun)': False,
#  'exists(이렇다/Adjective)': False,
#  'exists(일단/Noun)': False,
#  'exists(에로/Josa)': False,
#  'exists(끌다/Verb)': False,
#  'exists(엄마/Noun)': False,
#  'exists(한편/Noun)': False,
#  'exists(래/Josa)': False,
#  'exists(진정/Noun)': False,
#  'exists(대다/Verb)': False,
#  'exists(니깐/Josa)': False,
#  'exists(.../Punctuation)': False,
#  'exists(필름/Noun)': False,
#  'exists(훨씬/Adverb)': False,
#  'exists(린/Noun)': False,
#  'exists(폐지/Noun)': False,
#  'exists(최고다/Noun)': False,
#  'exists(기대/Noun)': False,
#  'exists(소소하다/Adjective)': False,
#  'exists(남/Noun)': False,
#  'exists(미국/Noun)': False,
#  'exists(공포영화/Noun)': False,
#  'exists(높다/Adjective)': False,
#  'exists(말/Noun)': False,
#  'exists(단순하다/Adjective)': False,
#  'exists(때우다/Adjective)': False,
#  'exists(막/Noun)': False,
#  'exists(1/Number)': False,
#  'exists(저렇게/Adverb)': False,
#  'exists(마/Noun)': False,
#  'exists(아름답다/Adjective)': False,
#  'exists(흠/Noun)': False,
#  'exists(들다/Verb)': False,
#  'exists(뭔/NounPrefix)': False,
#  'exists(귀/Noun)': False,
#  'exists(롭고/Josa)': False,
#  'exists(착하다/Adjective)': False,
#  'exists(다운/Noun)': False,
#  'exists(하고/Josa)': False,
#  'exists(시대/Noun)': False,
#  'exists(당시/Noun)': False,
#  'exists(병맛/Noun)': False,
#  'exists(심심하다/Adjective)': False,
#  'exists(마무리/Noun)': False,
#  'exists(본적/Noun)': False,
#  'exists(대충/Noun)': False,
#  'exists(개다/Verb)': False,
#  'exists(차다/Verb)': False,
#  'exists(에는/Josa)': False,
#  'exists(힐링/Noun)': False,
#  'exists(이나/Josa)': False,
#  'exists(현대/Noun)': False,
#  'exists(감흥/Noun)': False,
#  'exists(스/Noun)': False,
#  'exists(누구/Noun)': False,
#  'exists(예고편/Noun)': False,
#  'exists(끼리/Noun)': False,
#  'exists(즐겁다/Adjective)': False,
#  'exists(화이팅/Noun)': False,
#  'exists(한테/Josa)': False,
#  'exists(자신/Noun)': False,
#  'exists(너/Noun)': False,
#  'exists(끼다/Verb)': False,
#  'exists(터/Noun)': False,
#  'exists(에피소드/Noun)': False,
#  'exists(듬/Noun)': False,
#  'exists(제작비/Noun)': False,
#  'exists(데리/Noun)': False,
#  'exists(최고/Noun)': False,
#  'exists(오/Noun)': False,
#  'exists(토/Noun)': False,
#  'exists(궁금하다/Adjective)': False,
#  'exists(형/Noun)': False,
#  'exists(돼다/Verb)': False,
#  'exists(평생/Noun)': False,
#  'exists(부럽다/Adjective)': False,
#  'exists(조금/Noun)': False,
#  'exists(뮤지컬/Noun)': False,
#  'exists(공/Noun)': False,
#  'exists(평/Noun)': False,
#  'exists(아저씨/Noun)': False,
#  'exists(는/Josa)': False,
#  'exists(연/Noun)': False,
#  'exists(받다/Verb)': False,
#  'exists(감성/Noun)': False,
#  'exists(기다리다/Verb)': False,
#  'exists(!!!!/Punctuation)': False,
#  'exists(ost/Alpha)': False,
#  'exists(사이/Noun)': False,
#  'exists(우/Adverb)': False,
#  'exists(식/Noun)': False,
#  'exists(그리다/Verb)': False,
#  'exists(ㅡㅡ/KoreanParticle)': False,
#  'exists(%/Punctuation)': False,
#  'exists(했지만/Josa)': False,
#  'exists(중/Noun)': False,
#  'exists(비추다/Verb)': False,
#  'exists(의/Josa)': False,
#  'exists(등/Noun)': False,
#  'exists(그래서/Adverb)': False,
#  'exists(내다/Verb)': False,
#  'exists(비극/Noun)': False,
#  'exists(팬/Noun)': False,
#  'exists(욕/Noun)': False,
#  'exists(갖추다/Verb)': False,
#  'exists(네/Suffix)': False,
#  'exists(&/Punctuation)': False,
#  'exists(잼/Noun)': False,
#  'exists(추천/Noun)': False,
#  'exists(충분하다/Adjective)': False,
#  'exists(걍/Adverb)': False,
#  'exists(엔/Josa)': False,
#  'exists(산/Noun)': False,
#  'exists(대화/Noun)': False,
#  'exists(이니/Josa)': False,
#  'exists(빛/Noun)': False,
#  'exists(무한/Noun)': False,
#  'exists(그냥/Noun)': False,
#  'exists(가족/Noun)': False,
#  'exists(불다/Verb)': False,
#  'exists(길다/Adjective)': False,
#  'exists(시원하다/Adjective)': False,
#  'exists(형편/Noun)': False,
#  'exists(화려하다/Adjective)': False,
#  'exists(티/Noun)': False,
#  'exists(에게/Josa)': False,
#  'exists(개도/Noun)': False,
#  'exists(두/Noun)': False,
#  'exists(미가/Noun)': False,
#  'exists(007/Number)': False,
#  'exists(노/Noun)': False,
#  'exists(만이/Josa)': False,
#  'exists(영혼/Noun)': False,
#  'exists(끌/Noun)': False,
#  'exists(말다/Verb)': False,
#  'exists(이후/Noun)': False,
#  'exists(사람/Noun)': False,
#  'exists(느낌/Noun)': False,
#  'exists(마음/Noun)': False,
#  'exists(무협/Noun)': False,
#  'exists(과의/Josa)': False,
#  'exists(인간/Noun)': False,
#  'exists(?/Punctuation)': False,
#  'exists(80/Number)': False,
#  'exists(일/Noun)': False,
#  'exists(소재/Noun)': False,
#  'exists(게/Noun)': False,
#  'exists(터지다/Verb)': False,
#  'exists(새/Noun)': False,
#  'exists(해지/Noun)': False,
#  'exists(달라/Noun)': False,
#  'exists(나쁘다/Adjective)': False,
#  'exists(시사회/Noun)': False,
#  'exists(아이돌/Noun)': False,
#  'exists(성/Suffix)': False,
#  'exists(막장/Noun)': False,
#  'exists(이르다/Verb)': False,
#  'exists(메시지/Noun)': False,
#  'exists(관람/Noun)': False,
#  'exists(용이/Noun)': False,
#  'exists(불구/Noun)': False,
#  'exists(형님/Noun)': False,
#  'exists(보고/Noun)': False,
#  'exists(부모님/Noun)': False,
#  'exists(가슴/Noun)': False,
#  'exists(게이/Noun)': False,
#  'exists(영환/Noun)': False,
#  'exists(이영화/Noun)': False,
#  'exists("""/Punctuation)': False,
#  'exists(tv/Alpha)': False,
#  'exists(~~~~/Punctuation)': False,
#  'exists(맘/Noun)': False,
#  'exists(18/Number)': False,
#  'exists(느와르/Noun)': False,
#  'exists(라인/Noun)': False,
#  'exists(예산/Noun)': False,
#  'exists(뜻/Noun)': False,
#  'exists(쩝/Adverb)': False,
#  'exists(못/VerbPrefix)': False,
#  'exists(액션/Noun)': False,
#  'exists(을/Josa)': False,
#  'exists(가치/Noun)': False,
#  'exists(별점/Noun)': False,
#  'exists(매/Noun)': False,
#  'exists(고전/Noun)': False,
#  'exists(생각나다/Verb)': False,
#  'exists(스스로/Noun)': False,
#  'exists(다니다/Verb)': False,
#  'exists(빈약/Noun)': False,
#  'exists(과장/Noun)': False,
#  'exists(이/Noun)': False,
#  'exists(짝/Noun)': False,
#  'exists(까지/Josa)': False,
#  'exists(참신/Noun)': False,
#  'exists(자식/Noun)': False,
#  'exists(직접/Noun)': False,
#  'exists(때/Noun)': False,
#  'exists(잡다/Verb)': False,
#  'exists(으로는/Josa)': False,
#  'exists(랄/Noun)': False,
#  'exists(티비/Noun)': False,
#  'exists(이에요/Josa)': False,
#  'exists(과는/Josa)': False,
#  'exists(ㄱ/KoreanParticle)': False,
#  'exists(쯤/Suffix)': False,
#  'exists(서/Josa)': False,
#  'exists(그건/Adverb)': False,
#  'exists(바람/Noun)': False,
#  'exists(배역/Noun)': False,
#  'exists(만으로도/Josa)': False,
#  'exists(,./Punctuation)': False,
#  'exists(오락/Noun)': False,
#  'exists(방식/Noun)': False,
#  'exists(암/Noun)': False,
#  'exists(맡다/Verb)': False,
#  'exists(최/Noun)': False,
#  'exists(어울리다/Verb)': False,
#  'exists(으/Adverb)': False,
#  'exists(주/Noun)': False,
#  'exists(점/Noun)': False,
#  'exists(팀/Noun)': False,
#  'exists(원작/Noun)': False,
#  'exists(위해/Noun)': False,
#  'exists(따라가다/Verb)': False,
#  'exists(속/Noun)': False,
#  'exists(찌다/Verb)': False,
#  'exists(전반/Noun)': False,
#  'exists(망/Noun)': False,
#  'exists(살다/Verb)': False,
#  'exists(ㅇ/KoreanParticle)': False,
#  'exists(알바/Noun)': False,
#  'exists(지루함/Noun)': False,
#  'exists(첨/Adverb)': False,
#  'exists(부족하다/Adjective)': False,
#  'exists(딸/Noun)': False,
#  'exists((?)/Punctuation)': False,
#  'exists(얼/Noun)': False,
#  'exists(ㅋ/KoreanParticle)': False,
#  'exists(집/Noun)': False,
#  'exists(굳이/Noun)': False,
#  'exists(신/Noun)': False,
#  'exists(연속/Noun)': False,
#  'exists(필요/Noun)': False,
#  'exists(]/Punctuation)': False,
#  'exists(현재/Noun)': False,
#  'exists(기법/Noun)': False,
#  'exists(평론가/Noun)': False,
#  'exists(깨닫다/Verb)': False,
#  'exists(기적/Noun)': False,
#  'exists(여배우/Noun)': False,
#  'exists(입다/Verb)': False,
#  'exists(어떻다/Adjective)': False,
#  'exists(찡/Adverb)': False,
#  'exists(로서/Noun)': False,
#  'exists(드림/Noun)': False,
#  'exists(빨리/Adverb)': False,
#  'exists(의문/Noun)': False,
#  'exists(무섭다/Adjective)': False,
#  'exists(개/Suffix)': False,
#  'exists(레알/Noun)': False,
#  'exists(외국/Noun)': False,
#  'exists(형사/Noun)': False,
#  'exists(가능하다/Adjective)': False,
#  'exists(좋아지다/Adjective)': False,
#  'exists(해/Josa)': False,
#  'exists(멋지다/Adjective)': False,
#  'exists(거짓말/Noun)': False,
#  'exists(이유/Noun)': False,
#  'exists(빵/Noun)': False,
#  'exists(해/Noun)': False,
#  'exists(왜/Noun)': False,
#  'exists(놓치다/Verb)': False,
#  'exists(로봇/Noun)': False,
#  'exists(거지/Noun)': False,
#  'exists(..?/Punctuation)': False,
#  'exists(잘되다/Verb)': False,
#  'exists(흥미진진/Noun)': False,
#  'exists(국가/Noun)': False,
#  'exists(스토리/Noun)': False,
#  'exists(정의/Noun)': False,
#  'exists(진/Noun)': False,
#  'exists(아주/Noun)': False,
#  'exists(불편하다/Adjective)': False,
#  'exists(정치/Noun)': False,
#  'exists(이용/Noun)': False,
#  'exists(억지/Noun)': False,
#  'exists(우주/Noun)': False,
#  'exists(방영/Noun)': False,
#  'exists(를/Noun)': False,
#  'exists(21/Number)': False,
#  'exists(훈훈하다/Adjective)': False,
#  'exists(죠/Josa)': False,
#  'exists(어린이/Noun)': False,
#  'exists(수준/Noun)': False,
#  'exists(영화관/Noun)': False,
#  'exists(라서/Josa)': False,
#  'exists(싫다/Adjective)': False,
#  'exists(심/Noun)': False,
#  'exists(어른/Noun)': False,
#  'exists(영/Noun)': False,
#  'exists(틀다/Verb)': False,
#  'exists(으로도/Josa)': False,
#  'exists(에서도/Josa)': False,
#  'exists(요즘/Noun)': False,
#  'exists(표절/Noun)': False,
#  'exists(연결/Noun)': False,
#  'exists(쵝오/Noun)': False,
#  'exists(잃다/Verb)': False,
#  'exists(만들기/Noun)': False,
#  'exists(코난/Noun)': False,
#  'exists(7/Number)': False,
#  'exists(점주/Noun)': False,
#  'exists(판/Noun)': False,
#  'exists(스케일/Noun)': False,
#  'exists(한심하다/Adjective)': False,
#  'exists(리메이크/Noun)': False,
#  'exists(질/Noun)': False,
#  'exists(넘다/Verb)': False,
#  'exists(선생님/Noun)': False,
#  'exists(겨/Noun)': False,
#  'exists(몇번/Noun)': False,
#  'exists(예상/Noun)': False,
#  'exists(그거/Noun)': False,
#  'exists(순/Noun)': False,
#  'exists(ㅇㅇ/KoreanParticle)': False,
#  'exists(성룡/Noun)': False,
#  'exists(기본/Noun)': False,
#  'exists(처/Noun)': False,
#  'exists(캐/Noun)': False,
#  'exists(엉/Exclamation)': False,
#  'exists(인/Suffix)': False,
#  'exists(자리/Noun)': False,
#  'exists(진부/Noun)': False,
#  'exists(아쉬움/Noun)': False,
#  'exists(일품/Noun)': False,
#  'exists(인지/Noun)': False,
#  'exists(만큼/Josa)': False,
#  'exists(쉬다/Verb)': False,
#  'exists(빨/Noun)': False,
#  'exists(잊혀지다/Verb)': False,
#  'exists(홍콩영화/Noun)': False,
#  'exists(지/Josa)': False,
#  'exists(라도/Josa)': False,
#  'exists(치/Noun)': False,
#  'exists(망치다/Verb)': False,
#  'exists(투자/Noun)': False,
#  'exists(리얼/Noun)': False,
#  'exists(집중/Noun)': False,
#  'exists(에나/Josa)': False,
#  'exists(실화/Noun)': False,
#  'exists(외모/Noun)': False,
#  'exists(사다/Verb)': False,
#  'exists(중반/Noun)': False,
#  'exists(30/Number)': False,
#  'exists(아마/Noun)': False,
#  'exists(기르다/Verb)': False,
#  'exists(따르다/Verb)': False,
#  'exists(B/Alpha)': False,
#  'exists(끝/Noun)': False,
#  'exists(싶다/Verb)': False,
#  'exists(감독/Noun)': False,
#  'exists(특별하다/Adjective)': False,
#  'exists(해보다/Verb)': False,
#  'exists(후회/Noun)': False,
#  'exists(변태/Noun)': False,
#  'exists(상영/Noun)': False,
#  'exists(용도/Noun)': False,
#  'exists(프로/Noun)': False,
#  'exists(날리다/Verb)': False,
#  'exists(깨우다/Verb)': False,
#  'exists(칼/Noun)': False,
#  'exists(안다/Verb)': False,
#  'exists(거기/Noun)': False,
#  'exists(삶/Noun)': False,
#  'exists(양심/Noun)': False,
#  'exists(알다/Verb)': False,
#  'exists(감동/Noun)': False,
#  'exists(M/Alpha)': False,
#  'exists(판타지/Noun)': False,
#  'exists(ㅎㅎ/KoreanParticle)': False,
#  'exists(것/Noun)': False,
#  'exists(야하다/Adjective)': False,
#  'exists(색감/Noun)': False,
#  'exists(대표/Noun)': False,
#  'exists(요/Josa)': False,
#  'exists(씨/Noun)': False,
#  'exists(중/Suffix)': False,
#  'exists(다시/Noun)': False,
#  'exists(딱하다/Adjective)': False,
#  'exists(올해/Noun)': False,
#  'exists(원/Noun)': False,
#  'exists(에/Josa)': False,
#  'exists(주말/Noun)': False,
#  'exists(가지다/Verb)': False,
#  'exists(로는/Josa)': False,
#  'exists(아내/Noun)': False,
#  'exists(틈/Noun)': False,
#  'exists(반성/Noun)': False,
#  'exists(과거/Noun)': False,
#  'exists(땐/Noun)': False,
#  'exists(듯/Noun)': False,
#  'exists(이상/Noun)': False,
#  'exists(심장/Noun)': False,
#  'exists(감각/Noun)': False,
#  'exists(소장/Noun)': False,
#  'exists(와의/Josa)': False,
#  'exists(기다/Verb)': False,
#  'exists(미래/Noun)': False,
#  'exists(칠/Noun)': False,
#  'exists(맥/Noun)': False,
#  'exists(없다/Adjective)': False,
#  'exists(성도/Noun)': False,
#  'exists(만점/Noun)': False,
#  'exists(자극/Noun)': False,
#  'exists(작품/Noun)': False,
#  'exists(배경/Noun)': False,
#  'exists(역시/Noun)': False,
#  'exists(시청/Noun)': False,
#  'exists(주연/Noun)': False,
#  'exists(엇/VerbPrefix)': False,
#  'exists(성하/Noun)': False,
#  'exists(섹스/Noun)': False,
#  'exists(ㅅㅂ/KoreanParticle)': False,
#  'exists(에서는/Josa)': False,
#  'exists(왕/Noun)': False,
#  'exists(이/Josa)': False,
#  'exists(짱/Noun)': False,
#  'exists(이번/Noun)': False,
#  'exists(근래/Noun)': False,
#  'exists(글/Noun)': False,
#  'exists(아버지/Noun)': False,
#  'exists(깎다/Verb)': False,
#  'exists(본영/Noun)': False,
#  'exists(대중/Noun)': False,
#  'exists(만큼/Noun)': False,
#  'exists(레전드/Noun)': False,
#  'exists(급/Suffix)': False,
#  'exists(떨다/Verb)': False,
#  'exists(여준/Noun)': False,
#  'exists(밖에/Josa)': False,
#  'exists(많이/Adverb)': False,
#  'exists(기준/Noun)': False,
#  'exists(금/Noun)': False,
#  'exists(아빠/Noun)': False,
#  'exists(오그/Noun)': False,
#  'exists(어머니/Noun)': False,
#  'exists(한국/Noun)': False,
#  'exists(날/Noun)': False,
#  'exists(향/Noun)': False,
#  'exists(이해/Noun)': False,
#  'exists(갖다/Verb)': False,
#  'exists(정말로/Adverb)': False,
#  'exists(나머지/Noun)': False,
#  'exists(ㅜ/KoreanParticle)': False,
#  'exists(힘/Noun)': False,
#  'exists(나가다/Verb)': False,
#  'exists(영화계/Noun)': False,
#  'exists(정신/Noun)': False,
#  'exists(손발/Noun)': False,
#  'exists(로맨스/Noun)': False,
#  'exists(탓/Noun)': False,
#  'exists(다큐멘터리/Noun)': False,
#  'exists(낮다/Adjective)': False,
#  'exists(성인/Noun)': False,
#  'exists(인생/Noun)': False,
#  'exists(감상/Noun)': False,
#  'exists(장/Suffix)': False,
#  'exists(해결/Noun)': False,
#  'exists(순수하다/Adjective)': False,
#  'exists(근데/Adverb)': False,
#  'exists(♡/Foreign)': False,
#  'exists(편견/Noun)': False,
#  'exists(철학/Noun)': False,
#  'exists(소리/Noun)': False,
#  'exists(무술/Noun)': False,
#  'exists(스릴러/Noun)': False,
#  'exists(잠/Noun)': False,
#  'exists(싸다/Verb)': False,
#  'exists(접/Noun)': False,
#  'exists(소설/Noun)': False,
#  'exists(보단/Josa)': False,
#  'exists(개인/Noun)': False,
#  'exists(과/Josa)': False,
#  'exists(맨날/Adverb)': False,
#  'exists(남편/Noun)': False,
#  'exists(ㅅ/KoreanParticle)': False,
#  'exists(발/Noun)': False,
#  'exists(재밌다/Adjective)': False,
#  'exists(싸움/Noun)': False,
#  'exists(이라서/Josa)': False,
#  'exists(죽/Noun)': False,
#  'exists(학생/Noun)': False,
#  'exists(결말/Noun)': False,
#  'exists(게/Josa)': False,
#  'exists(란/Noun)': False,
#  'exists(뭔가/Noun)': False,
#  'exists(타/Noun)': False,
#  'exists(관/Noun)': False,
#  'exists(급/Noun)': False,
#  'exists(스트레스/Noun)': False,
#  'exists(일어나다/Verb)': False,
#  'exists(뒤/Noun)': False,
#  'exists(랑/Josa)': False,
#  'exists(파다/Verb)': False,
#  'exists(지도/Noun)': False,
#  'exists(네/Josa)': False,
#  'exists(붙다/Verb)': False,
#  'exists(오빠/Noun)': False,
#  'exists(때문/Noun)': False,
#  'exists(과/Noun)': False,
#  'exists(하라/Noun)': False,
#  'exists(말고/Josa)': False,
#  'exists(한국영/Noun)': False,
#  'exists(넘어가다/Verb)': False,
#  'exists(선/Noun)': False,
#  'exists(특히/Adverb)': False,
#  'exists(새벽/Noun)': False,
#  'exists(대/Suffix)': False,
#  'exists(웃음/Noun)': False,
#  'exists(선물/Noun)': False,
#  'exists(챙기다/Verb)': False,
#  'exists(모/Noun)': False,
#  'exists(고/Josa)': False,
#  'exists(참으로/Noun)': False,
#  'exists(DVD/Alpha)': False,
#  'exists(봄/Noun)': False,
#  'exists(너무나/Noun)': False,
#  'exists(목소리/Noun)': True,
#  'exists(상처/Noun)': False,
#  'exists(다르다/Adjective)': False,
#  'exists(차라리/Noun)': False,
#  'exists(억지로/Noun)': False,
#  'exists(이미지/Noun)': False,
#  'exists(~/Punctuation)': False,
#  'exists(꿀잼/Noun)': False,
#  'exists(바꾸다/Verb)': False,
#  'exists(이/Suffix)': False,
#  'exists(만/Suffix)': False,
#  'exists(ㅡ/KoreanParticle)': False,
#  'exists(함/Noun)': False,
#  'exists(조작/Noun)': False,
#  'exists(포르노/Noun)': False,
#  'exists(생생/Noun)': False,
#  'exists(뛰어나다/Adjective)': False,
#  'exists(음악/Noun)': False,
#  'exists(님/Suffix)': False,
#  'exists(별로/Noun)': False,
#  'exists(이랑/Josa)': False,
#  'exists(빠르다/Adjective)': False,
#  'exists(기억나다/Verb)': False,
#  'exists(어설픈/Noun)': False,
#  'exists(장면/Noun)': False,
#  'exists(쫌/Noun)': False,
#  'exists(x/Alpha)': False,
#  'exists(동시/Noun)': False,
#  'exists(의도/Noun)': False,
#  'exists(스크린/Noun)': False,
#  'exists(좀비/Noun)': False,
#  'exists(간/Noun)': False,
#  'exists(,/Punctuation)': False,
#  'exists(잔인/Noun)': False,
#  'exists(음/Noun)': False,
#  'exists(우리나라/Noun)': False,
#  'exists(//Punctuation)': False,
#  'exists(발전/Noun)': False,
#  'exists(참다/Verb)': False,
#  'exists(유발/Noun)': False,
#  'exists(남자/Noun)': False,
#  'exists(40/Number)': False,
#  'exists(부터/Noun)': False,
#  'exists(가다/Verb)': False,
#  'exists(생각/Noun)': False,
#  'exists(겠다/Verb)': False,
#  'exists(아직까지/Noun)': False,
#  'exists(물다/Verb)': False,
#  'exists(화/Suffix)': False,
#  'exists(그림/Noun)': False,
#  'exists(치고/Josa)': False,
#  'exists(어쩌다/Verb)': False,
#  'exists(밑/Noun)': False,
#  'exists(웃다/Verb)': False,
#  'exists(사회/Noun)': False,
#  'exists(번째/Suffix)': False,
#  'exists(시리즈/Noun)': False,
#  'exists(설마/Noun)': False,
#  'exists(해주다/Verb)': False,
#  'exists(다만/Noun)': False,
#  'exists(돈/Noun)': False,
#  'exists(얼마/Noun)': False,
#  'exists(영국/Noun)': False,
#  'exists(첨/Noun)': False,
#  'exists(전혀/Noun)': False,
#  'exists(앉다/Verb)': False,
#  'exists(개봉/Noun)': False,
#  'exists(난해/Noun)': False,
#  'exists(기발/Noun)': False,
#  'exists(남녀/Noun)': False,
#  'exists(완벽하다/Adjective)': False,
#  'exists(고/Noun)': False,
#  'exists(수작/Noun)': False,
#  'exists(긴장감/Noun)': False,
#  'exists(연기력/Noun)': False,
#  'exists(멜로/Noun)': False,
#  'exists(극장/Noun)': False,
#  'exists(현실/Noun)': False,
#  'exists(훌륭하다/Adjective)': False,
#  'exists(내용/Noun)': False,
#  'exists(푹/Noun)': False,
#  'exists(잘생기다/Adjective)': False,
#  'exists(조연/Noun)': False,
#  'exists(싸구려/Noun)': False,
#  'exists(_/Punctuation)': False,
#  'exists(저/Determiner)': False,
#  'exists(섬세/Noun)': False,
#  'exists(인/Josa)': False,
#  'exists(리즈/Noun)': False,
#  'exists(짜다/Verb)': False,
#  'exists(에게는/Josa)': False,
#  'exists(꽤/Noun)': False,
#  'exists(줄거리/Noun)': False,
#  'exists(명/Noun)': False,
#  'exists(으론/Josa)': False,
#  'exists(피해자/Noun)': False,
#  'exists(몇/NounPrefix)': False,
#  'exists(사라지다/Verb)': False,
#  'exists(보이/Noun)': False,
#  'exists(채널/Noun)': False,
#  'exists(시키다/Verb)': False,
#  'exists(반전/Noun)': False,
#  'exists(마치/Noun)': False,
#  'exists(광고/Noun)': False,
#  'exists(길/Noun)': False,
#  'exists(만의/Josa)': False,
#  'exists(존/Noun)': False,
#  'exists(이지만/Josa)': False,
#  'exists(언니/Noun)': False,
#  'exists(이면/Noun)': False,
#  'exists(신기하다/Adjective)': False,
#  'exists(시절/Noun)': False,
#  'exists(만으로/Josa)': False,
#  'exists(시도/Noun)': False,
#  'exists(슬프다/Adjective)': False,
#  'exists(지겹다/Adjective)': False,
#  'exists(성/Noun)': False,
#  'exists(점도/Noun)': False,
#  'exists(편집/Noun)': False,
#  'exists(멀다/Adjective)': False,
#  'exists(어처구니/Noun)': False,
#  'exists(내생/Noun)': False,
#  'exists(어디/Noun)': False,
#  'exists(연애/Noun)': False,
#  'exists(값/Noun)': False,
#  'exists(전부/Noun)': False,
#  'exists(관점/Noun)': False,
#  'exists(확/Noun)': False,
#  'exists(봣/Noun)': False,
#  'exists(존재/Noun)': False,
#  'exists(번/Noun)': False,
#  'exists(잇다/Verb)': False,
#  'exists(돋다/Adjective)': False,
#  'exists(~!!/Punctuation)': False,
#  'exists(볼거리/Noun)': False,
#  'exists(눈/Noun)': False,
#  'exists(솔직하다/Adjective)': False,
#  'exists(러닝/Noun)': False,
#  'exists(흑/Adverb)': False,
#  'exists(영화로/Noun)': False,
#  'exists(실패/Noun)': False,
#  'exists(달달/Noun)': False,
#  'exists(세기/Noun)': False,
#  'exists(개/Noun)': False,
#  'exists(줄/Noun)': False,
#  'exists(부모/Noun)': False,
#  'exists(시나리오/Noun)': False,
#  'exists(태어나다/Verb)': False,
#  'exists(흥행/Noun)': False,
#  'exists(도/Noun)': False,
#  'exists(첫/Noun)': False,
#  'exists(재미없다/Adjective)': False,
#  'exists(살리다/Verb)': False,
#  'exists(후반/Noun)': False,
#  'exists(모으다/Verb)': False,
#  'exists(바라보다/Verb)': False,
#  'exists(몸매/Noun)': False,
#  'exists(새롭다/Adjective)': False,
#  'exists(진짜/Noun)': True,
#  'exists(에서/Josa)': False,
#  'exists(통/Noun)': False,
#  'exists(게임/Noun)': False,
#  'exists(./Punctuation)': False,
#  'exists(인상/Noun)': False,
#  'exists(악마/Noun)': False,
#  'exists(나타나다/Verb)': False,
#  'exists(엄청나다/Adjective)': False,
#  'exists(원래/Noun)': False,
#  'exists(자살/Noun)': False,
#  'exists(결론/Noun)': False,
#  'exists(년전/Noun)': False,
#  'exists(외계인/Noun)': False,
#  'exists(흑인/Noun)': False,
#  'exists(이렇게/Adverb)': False,
#  'exists(이든/Josa)': False,
#  'exists(가요/Noun)': False,
#  'exists(봐/Noun)': False,
#  'exists(위대하다/Adjective)': False,
#  'exists(내내/Noun)': False,
#  'exists(심하다/Adjective)': False,
#  'exists(100/Number)': False,
#  'exists(웃기다/Verb)': False,
#  'exists(그렇다고/Conjunction)': False,
#  'exists(되다/Verb)': False,
#  'exists(과정/Noun)': False,
#  'exists(성은/Noun)': False,
#  'exists(예능/Noun)': False,
#  'exists(진리/Noun)': False,
#  'exists(놀랍다/Adjective)': False,
#  'exists(짓/Noun)': False,
#  'exists(절대/Noun)': False,
#  'exists(부끄럽다/Adjective)': False,
#  'exists(""""/Punctuation)': False,
#  'exists(빛나다/Verb)': False,
#  'exists(내면/Noun)': False,
#  'exists(늘/Noun)': False,
#  'exists(젊다/Adjective)': False,
#  'exists(딱/VerbPrefix)': False,
#  'exists(모두/Noun)': False,
#  'exists(놀다/Verb)': False,
#  'exists(쪽/Noun)': False,
#  'exists(나/Noun)': False,
#  'exists(시청률/Noun)': False,
#  'exists(그/Determiner)': False,
#  'exists(박수/Noun)': False,
#  'exists(어제/Noun)': False,
#  'exists(...?/Punctuation)': False,
#  'exists(쩔다/Verb)': False,
#  'exists(크리스마스/Noun)': False,
#  'exists(덜/Noun)': False,
#  'exists(미모/Noun)': False,
#  'exists(자다/Verb)': False,
#  'exists(효과/Noun)': False,
#  'exists(에선/Josa)': False,
#  'exists(이다/Verb)': False,
#  'exists(아예/Noun)': False,
#  'exists(예술/Noun)': False,
#  'exists(몰다/Verb)': False,
#  'exists(관심/Noun)': False,
#  'exists(로/Noun)': False,
#  'exists(자유/Noun)': False,
#  'exists(외/Noun)': False,
#  'exists(그걸/Adverb)': False,
#  'exists(듣다/Verb)': False,
#  'exists(무척/Noun)': False,
#  'exists(다양하다/Adjective)': False,
#  'exists(필요하다/Adjective)': False,
#  'exists(조합/Noun)': False,
#  'exists(주다/Verb)': False,
#  'exists(보내다/Verb)': False,
#  'exists(ㅉㅉ/KoreanParticle)': False,
#  'exists(채우다/Verb)': False,
#  'exists(우정/Noun)': False,
#  'exists(볼게다/Verb)': False,
#  'exists(상상력/Noun)': False,
#  'exists(12/Number)': False,
#  'exists(지우다/Verb)': False,
#  'exists(행복/Noun)': False,
#  'exists(쓰래/Noun)': False,
#  'exists(한마디/Noun)': False,
#  'exists(흐름/Noun)': False,
#  'exists(배/Noun)': False,
#  'exists(어색하다/Adjective)': False,
#  'exists(귀신/Noun)': False,
#  'exists(같다/Adjective)': False,
#  'exists(확실하다/Adjective)': False,
#  'exists(만하/Noun)': False,
#  'exists(괜찮다/Adjective)': False,
#  'exists(6/Number)': False,
#  'exists(포기/Noun)': False,
#  'exists(별루/Noun)': False,
#  'exists(갈수록/Noun)': False,
#  'exists(당연하다/Adjective)': False,
#  'exists(인데/Josa)': False,
#  'exists(무것/Noun)': False,
#  'exists(만남/Noun)': False,
#  'exists(생애/Noun)': False,
#  'exists(총/Noun)': False,
#  'exists(폭력/Noun)': False,
#  'exists(상/Suffix)': False,
#  'exists(젠/Noun)': False,
#  'exists(방금/Noun)': False,
#  'exists(은/Josa)': False,
#  'exists(부족/Noun)': False,
#  'exists(작다/Adjective)': False,
#  'exists(있다/Adjective)': False,
#  'exists(경찰/Noun)': False,
#  'exists(나라/Noun)': False,
#  'exists(살아가다/Verb)': False,
#  'exists(방/Noun)': False,
#  'exists(이루다/Verb)': False,
#  'exists(올리다/Verb)': False,
#  'exists(나이/Noun)': False,
#  'exists(넣다/Verb)': False,
#  'exists(들이다/Verb)': False,
#  'exists(한/Determiner)': False,
#  'exists(매우/Noun)': False,
#  'exists(시작/Noun)': False,
#  'exists(우와/Exclamation)': False,
#  'exists(여서/Josa)': False,
#  'exists(실력/Noun)': False,
#  'exists(무/Noun)': False,
#  'exists(오다/Verb)': False,
#  'exists(19/Number)': False,
#  'exists(어설프/Noun)': False,
#  'exists(한계/Noun)': False,
#  'exists(주변/Noun)': False,
#  'exists(분위기/Noun)': False,
#  'exists(풋풋/Noun)': False,
#  'exists(처음/Noun)': False,
#  'exists(만/Josa)': False,
#  'exists(께/Josa)': False,
#  'exists(낫다/Noun)': False,
#  'exists(이래서/Josa)': False,
#  'exists(웃기/Noun)': False,
#  'exists(우리/Noun)': False,
#  'exists(패러디/Noun)': False,
#  'exists(피/Noun)': False,
#  'exists(두다/Verb)': False,
#  'exists(연예인/Noun)': False,
#  'exists(전설/Noun)': False,
#  'exists(뜨다/Verb)': False,
#  'exists(상당하다/Adjective)': False,
#  'exists(짜증/Noun)': True,
#  'exists(발견/Noun)': False,
#  'exists(전/Noun)': False,
#  'exists(캐리/Noun)': False,
#  'exists(머리/Noun)': False,
#  'exists(소름/Noun)': False,
#  'exists(비현실적/Noun)': False,
#  'exists(이네/Josa)': False,
#  'exists(최근/Noun)': False,
#  'exists(이미/Adverb)': False,
#  'exists(들어오다/Verb)': False,
#  'exists(사건/Noun)': False,
#  'exists(!/Punctuation)': False,
#  'exists(해석/Noun)': False,
#  'exists(덕분/Noun)': False,
#  'exists(왠지/Adverb)': False,
#  'exists(대의/Noun)': False,
#  'exists(떨어지다/Verb)': False,
#  'exists(잠들다/Verb)': False,
#  'exists(만들다/Verb)': False,
#  'exists(단지/Noun)': False,
#  'exists(메다/Verb)': False,
#  'exists(범죄/Noun)': False,
#  'exists(인지/Josa)': False,
#  'exists(행동/Noun)': False,
#  'exists(강렬하다/Adjective)': False,
#  'exists(바라다/Verb)': False,
#  'exists(두/Josa)': False,
#  'exists(불륜/Noun)': False,
#  'exists(스럽다/Adjective)': False,
#  'exists(불가/Noun)': False,
#  'exists(뿐/Suffix)': False,
#  'exists(이라도/Josa)': False,
#  'exists(자/Suffix)': False,
#  'exists(라고/Josa)': False,
#  'exists(뿐이다/Adjective)': False,
#  'exists(마다/Josa)': False,
#  'exists(고양이/Noun)': False,
#  'exists(나오다/Verb)': False,
#  'exists(니/Josa)': False,
#  'exists(실제/Noun)': False,
#  'exists(:/Punctuation)': False,
#  'exists(로맨틱/Noun)': False,
#  'exists(,,,,/Punctuation)': False,
#  'exists(세상/Noun)': False,
#  'exists(따로/Adverb)': False,
#  'exists(드리다/Verb)': False,
#  'exists(구성/Noun)': False,
#  'exists(글쎄/Noun)': False,
#  'exists(진심/Noun)': False,
#  'exists(괴물/Noun)': False,
#  'exists(이여/Josa)': False,
#  'exists(스러운/Josa)': False,
#  'exists(세계/Noun)': False,
#  ...}

# %%
term_exists(train_docs[0][0])
# Out:
# {'exists(든/Josa)': False,
#  'exists(소장/Noun)': False,
#  'exists(수고/Noun)': False,
#  'exists(힐링/Noun)': False,
#  'exists(방식/Noun)': False,
#  'exists(성룡/Noun)': False,
#  'exists(인지/Josa)': False,
#  'exists(조잡/Noun)': False,
#  'exists(예능/Noun)': False,
#  'exists(시키다/Verb)': False,
#  'exists(굉장하다/Adjective)': False,
#  'exists(등/Noun)': False,
#  'exists(그렇다고/Conjunction)': False,
#  'exists(남/Noun)': False,
#  'exists(보단/Josa)': False,
#  'exists(CG/Alpha)': False,
#  'exists(가수/Noun)': False,
#  'exists(ㅠㅜ/KoreanParticle)': False,
#  'exists(야동/Noun)': False,
#  'exists(괜히/Adverb)': False,
#  'exists(임/Noun)': False,
#  'exists(시나리오/Noun)': False,
#  'exists(끼리/Noun)': False,
#  'exists(!!/Punctuation)': False,
#  'exists(독립영화/Noun)': False,
#  'exists(D/Alpha)': False,
#  'exists(이라니/Josa)': False,
#  'exists(이해/Noun)': False,
#  'exists(궁금하다/Adjective)': False,
#  'exists(형사/Noun)': False,
#  'exists(장/Suffix)': False,
#  'exists(스릴/Noun)': False,
#  'exists(별점/Noun)': False,
#  'exists(지루하다/Adjective)': False,
#  'exists(여/Josa)': False,
#  'exists(유쾌/Noun)': False,
#  'exists(ㅉㅉ/KoreanParticle)': False,
#  'exists(9/Number)': False,
#  'exists(착하다/Adjective)': False,
#  'exists(잊다/Verb)': False,
#  'exists(자기/Noun)': False,
#  'exists(둘/Noun)': False,
#  'exists(매다/Verb)': False,
#  'exists(위해/Noun)': False,
#  'exists(설레다/Adjective)': False,
#  'exists(완성/Noun)': False,
#  'exists(시간/Noun)': False,
#  'exists(굿/Noun)': False,
#  'exists(남녀/Noun)': False,
#  'exists(행복/Noun)': False,
#  'exists(이자/Noun)': False,
#  'exists(빨리/Adverb)': False,
#  'exists(주연/Noun)': False,
#  'exists(이렇게/Adverb)': False,
#  'exists(훨씬/Adverb)': False,
#  'exists(아주/Noun)': False,
#  'exists(년대/Noun)': False,
#  'exists(들어가다/Verb)': False,
#  'exists(결말/Noun)': False,
#  'exists(화/Suffix)': False,
#  'exists(대부분/Noun)': False,
#  'exists(최강/Noun)': False,
#  'exists(화려하다/Adjective)': False,
#  'exists(생애/Noun)': False,
#  'exists(이래서/Josa)': False,
#  'exists(평론가/Noun)': False,
#  'exists(,,,/Punctuation)': False,
#  'exists(그리고/Conjunction)': False,
#  'exists(배/Noun)': False,
#  'exists(그다지/Noun)': False,
#  'exists(프로그램/Noun)': False,
#  'exists(청소년/Noun)': False,
#  'exists(좋다/Adjective)': False,
#  'exists(두/Josa)': False,
#  'exists(언제/Noun)': False,
#  'exists(이보/Noun)': False,
#  'exists(보기/Noun)': False,
#  'exists(죽이다/Verb)': False,
#  'exists(으로/Josa)': False,
#  'exists(마지막/Noun)': False,
#  'exists(문제/Noun)': False,
#  'exists(까지는/Josa)': False,
#  'exists(떠오르다/Verb)': False,
#  'exists(손/Noun)': False,
#  'exists(새/Noun)': False,
#  'exists(후반/Noun)': False,
#  'exists(메세지/Noun)': False,
#  'exists(방영/Noun)': False,
#  'exists(흥미/Noun)': False,
#  'exists(초반/Noun)': False,
#  'exists(기발/Noun)': False,
#  'exists(걸리다/Verb)': False,
#  'exists(책/Noun)': False,
#  'exists(아쉽다/Adjective)': False,
#  'exists(내/Noun)': False,
#  'exists(드림/Noun)': False,
#  'exists(걸다/Verb)': False,
#  'exists(몇/NounPrefix)': False,
#  'exists(덕/Noun)': False,
#  'exists(기분/Noun)': False,
#  'exists(미치다/Adjective)': False,
#  'exists(영환/Noun)': False,
#  'exists(.../Punctuation)': False,
#  'exists(전부/Noun)': False,
#  'exists(잡다/Verb)': False,
#  'exists(확인/Noun)': False,
#  'exists(어디/Noun)': False,
#  'exists(가보다/Verb)': False,
#  'exists(즐기다/Verb)': False,
#  'exists(광고/Noun)': False,
#  'exists(영상/Noun)': False,
#  'exists(용도/Noun)': False,
#  'exists(영혼/Noun)': False,
#  'exists(파다/Verb)': False,
#  'exists(없이/Adverb)': False,
#  'exists(스릴러/Noun)': False,
#  'exists(나름/Noun)': False,
#  'exists(되게/Adverb)': False,
#  'exists(할머니/Noun)': False,
#  'exists(~~~~/Punctuation)': False,
#  'exists(작/Noun)': False,
#  'exists(최/Noun)': False,
#  'exists(전설/Noun)': False,
#  'exists(상황/Noun)': False,
#  'exists(뮤지컬/Noun)': False,
#  'exists(감흥/Noun)': False,
#  'exists(황당/Noun)': False,
#  'exists(여배우/Noun)': False,
#  'exists(치밀/Noun)': False,
#  'exists(그리다/Verb)': False,
#  'exists(추억/Noun)': False,
#  'exists(첨/Adverb)': False,
#  'exists(어디서/Adverb)': False,
#  'exists(과/Josa)': False,
#  'exists(형제/Noun)': False,
#  'exists(여러/Noun)': False,
#  'exists(!!!!/Punctuation)': False,
#  'exists(tv/Alpha)': False,
#  'exists(반성/Noun)': False,
#  'exists(얼/Noun)': False,
#  'exists(진/Noun)': False,
#  'exists(평생/Noun)': False,
#  'exists(오히려/Noun)': False,
#  'exists(다큐멘터리/Noun)': False,
#  'exists(아무렇다/Adjective)': False,
#  'exists(어떻다/Adjective)': False,
#  'exists(성은/Noun)': False,
#  'exists(줍다/Verb)': False,
#  'exists(관객/Noun)': False,
#  'exists((/Punctuation)': False,
#  'exists(감히/Noun)': False,
#  'exists(이야기/Noun)': False,
#  'exists(급/Suffix)': False,
#  'exists(효과/Noun)': False,
#  'exists(구/Noun)': False,
#  'exists(감탄/Noun)': False,
#  'exists(다시/Noun)': False,
#  'exists(손발/Noun)': False,
#  'exists(재/Noun)': False,
#  'exists(참다/Verb)': False,
#  'exists(뻔하다/Adjective)': False,
#  'exists(계/Suffix)': False,
#  'exists(조금/Noun)': False,
#  'exists(보이/Noun)': False,
#  'exists(연기/Noun)': False,
#  'exists(알다/Verb)': False,
#  'exists(의/Noun)': False,
#  'exists(90/Number)': False,
#  'exists(쵝오/Noun)': False,
#  'exists(발견/Noun)': False,
#  'exists(기억나다/Verb)': False,
#  'exists(막히다/Verb)': False,
#  'exists(스러운/Josa)': False,
#  'exists(처럼/Noun)': False,
#  'exists(최고/Noun)': False,
#  'exists(신경/Noun)': False,
#  'exists(국가/Noun)': False,
#  'exists(~!!/Punctuation)': False,
#  'exists(잘/VerbPrefix)': False,
#  'exists(조작/Noun)': False,
#  'exists(때우다/Adjective)': False,
#  'exists(비교/Noun)': False,
#  'exists(섹시하다/Adjective)': False,
#  'exists(쩝/Adverb)': False,
#  'exists(식/Noun)': False,
#  'exists(역대/Noun)': False,
#  'exists(결론/Noun)': False,
#  'exists(체/Noun)': False,
#  'exists(의미/Noun)': False,
#  'exists(그대로/Noun)': False,
#  'exists(개인/Noun)': False,
#  'exists(좀비/Noun)': False,
#  'exists(끼/Noun)': False,
#  'exists(군대/Noun)': False,
#  'exists(끌다/Verb)': False,
#  'exists(범인/Noun)': False,
#  'exists(학교/Noun)': False,
#  'exists(애/Noun)': False,
#  'exists(막장/Noun)': False,
#  'exists(정서/Noun)': False,
#  'exists(다행/Noun)': False,
#  'exists(부터/Josa)': False,
#  'exists(뿐/Suffix)': False,
#  'exists(머/Noun)': False,
#  'exists(돌아가다/Verb)': False,
#  'exists(개뿔/Noun)': False,
#  'exists(용/Noun)': False,
#  'exists(개막/Noun)': False,
#  'exists(교육/Noun)': False,
#  'exists(만이/Josa)': False,
#  'exists(멋있다/Adjective)': False,
#  'exists(낳다/Verb)': False,
#  'exists(기다리다/Verb)': False,
#  'exists(아/Josa)': False,
#  'exists(거인/Noun)': False,
#  'exists(짜증/Noun)': True,
#  'exists(반전/Noun)': False,
#  'exists(대다/Verb)': False,
#  'exists(제대로/Noun)': False,
#  'exists(뭔가/Noun)': False,
#  'exists("""""""/Punctuation)': False,
#  'exists(제로/Noun)': False,
#  'exists(이연걸/Noun)': False,
#  'exists(만큼/Josa)': False,
#  'exists(물/Noun)': False,
#  'exists(욕/Noun)': False,
#  'exists(전문가/Noun)': False,
#  'exists(모자라다/Verb)': False,
#  'exists(불쾌/Noun)': False,
#  'exists(린다/Noun)': False,
#  'exists(에/Josa)': False,
#  'exists(무시/Noun)': False,
#  'exists(순수하다/Adjective)': False,
#  'exists(찾아보다/Verb)': False,
#  'exists(같다/Adjective)': False,
#  'exists(감다/Verb)': False,
#  'exists(연애/Noun)': False,
#  'exists(하니/Noun)': False,
#  'exists(기르다/Verb)': False,
#  'exists(신선하다/Adjective)': False,
#  'exists(이라도/Josa)': False,
#  'exists(내용/Noun)': False,
#  'exists(꺼/Suffix)': False,
#  'exists(바라다/Verb)': False,
#  'exists(요소/Noun)': False,
#  'exists(학생/Noun)': False,
#  'exists(1/Number)': False,
#  'exists(갈수록/Noun)': False,
#  'exists(다운/Noun)': False,
#  'exists(묘/Noun)': False,
#  'exists(으로써/Josa)': False,
#  'exists(단/Noun)': False,
#  'exists(신다/Verb)': False,
#  'exists(질리/Noun)': False,
#  'exists(틈/Noun)': False,
#  'exists(으론/Josa)': False,
#  'exists(세번/Noun)': False,
#  'exists(연결/Noun)': False,
#  'exists(다하다/Verb)': False,
#  'exists(촌스럽다/Adjective)': False,
#  'exists(포르노/Noun)': False,
#  'exists(인가/Josa)': False,
#  'exists(두다/Verb)': False,
#  'exists(너무/Noun)': False,
#  'exists(점주/Noun)': False,
#  'exists(케이블/Noun)': False,
#  'exists(남아/Noun)': False,
#  'exists(그걸/Adverb)': False,
#  'exists(다/Josa)': False,
#  'exists(노/Noun)': False,
#  'exists(읽다/Verb)': False,
#  'exists(소설/Noun)': False,
#  'exists(하다/Verb)': False,
#  'exists(;;;/Punctuation)': False,
#  'exists(기세/Noun)': False,
#  'exists(영어/Noun)': False,
#  'exists(폭력/Noun)': False,
#  'exists(니/Noun)': False,
#  'exists(혼자/Noun)': False,
#  'exists(봣/Noun)': False,
#  'exists(정도/Noun)': False,
#  'exists(내/Determiner)': False,
#  'exists(만/Suffix)': False,
#  'exists(하나로/Noun)': False,
#  'exists(파/Noun)': False,
#  'exists(잔/Noun)': False,
#  'exists(리얼/Noun)': False,
#  'exists(&/Punctuation)': False,
#  'exists(집/Noun)': False,
#  'exists(적절하다/Adjective)': False,
#  'exists(달다/Verb)': False,
#  'exists(나/Noun)': False,
#  'exists(으로는/Josa)': False,
#  'exists(까지/Noun)': False,
#  'exists(빠지다/Verb)': False,
#  'exists(이라서/Josa)': False,
#  'exists(..../Punctuation)': False,
#  'exists(무언가/Noun)': False,
#  'exists(중국/Noun)': False,
#  'exists(코드/Noun)': False,
#  'exists(애기/Noun)': False,
#  'exists(부터/Noun)': False,
#  'exists(많다/Adjective)': False,
#  'exists(중요하다/Adjective)': False,
#  'exists(캐스팅/Noun)': False,
#  'exists(라면/Noun)': False,
#  'exists(빵/Noun)': False,
#  'exists(있다/Adjective)': False,
#  'exists(개봉/Noun)': False,
#  'exists(사다/Verb)': False,
#  'exists(당하다/Adjective)': False,
#  'exists(분명하다/Adjective)': False,
#  'exists(다/Adverb)': False,
#  'exists(죽음/Noun)': False,
#  'exists(주기/Noun)': False,
#  'exists(만/Josa)': False,
#  'exists(^/Punctuation)': False,
#  'exists(감정/Noun)': False,
#  'exists(판타지/Noun)': False,
#  'exists(,./Punctuation)': False,
#  'exists(보/Noun)': False,
#  'exists(약하다/Adjective)': False,
#  'exists(리즈/Noun)': False,
#  'exists(숨기다/Verb)': False,
#  'exists(애니/Noun)': False,
#  'exists(실망/Noun)': False,
#  'exists(이란/Noun)': False,
#  'exists(끌/Noun)': False,
#  'exists(이끌다/Verb)': False,
#  'exists(여성/Noun)': False,
#  'exists(흘러가다/Verb)': False,
#  'exists(로/Noun)': False,
#  'exists(가슴/Noun)': False,
#  'exists(시도/Noun)': False,
#  'exists(만으로/Josa)': False,
#  'exists(8/Number)': False,
#  'exists(표/Noun)': False,
#  'exists(한국인/Noun)': False,
#  'exists(비슷하다/Adjective)': False,
#  'exists(추천/Noun)': False,
#  'exists(OST/Alpha)': False,
#  'exists(간만/Noun)': False,
#  'exists(무엇/Noun)': False,
#  'exists(21/Number)': False,
#  'exists(러브/Noun)': False,
#  'exists(불륜/Noun)': False,
#  'exists(올해/Noun)': False,
#  'exists(느리다/Adjective)': False,
#  'exists(주성치/Noun)': False,
#  'exists(이유/Noun)': False,
#  'exists(영/Noun)': False,
#  'exists(아무리/Adverb)': False,
#  'exists(병맛/Noun)': False,
#  'exists(대해/Noun)': False,
#  'exists(로는/Josa)': False,
#  'exists(-/Punctuation)': False,
#  'exists(네/Determiner)': False,
#  'exists(죄/Noun)': False,
#  'exists(간다/Noun)': False,
#  'exists(얻다/Verb)': False,
#  'exists(치다/Verb)': False,
#  'exists(지우다/Verb)': False,
#  'exists(흘리다/Verb)': False,
#  'exists(싫다/Adjective)': False,
#  'exists(돌아오다/Verb)': False,
#  'exists(회/Noun)': False,
#  'exists(덥다/Adjective)': False,
#  'exists(거지/Noun)': False,
#  'exists(그/Determiner)': False,
#  'exists(길/Noun)': False,
#  'exists(단연/Noun)': False,
#  'exists(예상/Noun)': False,
#  'exists(지만/Josa)': False,
#  'exists(빛나다/Verb)': False,
#  'exists(낫다/Noun)': False,
#  'exists(비다/Verb)': False,
#  'exists(곳/Noun)': False,
#  'exists(끄다/Verb)': False,
#  'exists(문화/Noun)': False,
#  'exists(갖추다/Verb)': False,
#  'exists(죠/Josa)': False,
#  'exists(라니/Josa)': False,
#  'exists(이여/Josa)': False,
#  'exists(까다/Verb)': False,
#  'exists(날리다/Verb)': False,
#  'exists(귀엽다/Adjective)': False,
#  'exists(그것/Noun)': False,
#  'exists(미가/Noun)': False,
#  'exists(성인/Noun)': False,
#  'exists(이어지다/Verb)': False,
#  'exists(해서/Josa)': False,
#  'exists(작가/Noun)': False,
#  'exists(인정/Noun)': False,
#  'exists(흥미롭다/Adjective)': False,
#  'exists(80/Number)': False,
#  'exists(도/Josa)': False,
#  'exists(줌/Noun)': False,
#  'exists(웃기다/Verb)': False,
#  'exists(해지/Noun)': False,
#  'exists(철학/Noun)': False,
#  'exists(북한/Noun)': False,
#  'exists(라/Josa)': False,
#  'exists(?/Punctuation)': False,
#  'exists(보고/Noun)': False,
#  'exists(훈훈하다/Adjective)': False,
#  'exists(몸/Noun)': False,
#  'exists(일/Noun)': False,
#  'exists(이/Noun)': False,
#  'exists(워/Noun)': False,
#  'exists(잊혀지다/Verb)': False,
#  'exists(아픔/Noun)': False,
#  'exists(조/Noun)': False,
#  'exists(귀/Noun)': False,
#  'exists(아직까지/Noun)': False,
#  'exists(똥/Noun)': False,
#  'exists(따다/Verb)': False,
#  'exists(수작/Noun)': False,
#  'exists(게다가/Noun)': False,
#  'exists(원래/Noun)': False,
#  'exists(불/Noun)': False,
#  'exists(성/Suffix)': False,
#  'exists(펑펑/Noun)': False,
#  'exists(잘되다/Verb)': False,
#  'exists(잼/Noun)': False,
#  'exists(웃음/Noun)': False,
#  'exists(암튼/Adverb)': False,
#  'exists(가지다/Verb)': False,
#  'exists(부족/Noun)': False,
#  'exists(스런/Josa)': False,
#  'exists(근데/Adverb)': False,
#  'exists(몰입도/Noun)': False,
#  'exists(담다/Verb)': False,
#  'exists(소름/Noun)': False,
#  'exists(시사회/Noun)': False,
#  'exists(존나/Noun)': False,
#  'exists(세계/Noun)': False,
#  'exists(놀라다/Verb)': False,
#  'exists(만화/Noun)': False,
#  'exists(친구/Noun)': False,
#  'exists(무/Noun)': False,
#  'exists(프로/Noun)': False,
#  'exists(맥/Noun)': False,
#  'exists(이래/Josa)': False,
#  'exists(라지/Noun)': False,
#  'exists(마/Noun)': False,
#  'exists(고맙다/Adjective)': False,
#  'exists(덜/Noun)': False,
#  'exists(몰다/Verb)': False,
#  'exists(각본/Noun)': False,
#  'exists(걍/Adverb)': False,
#  'exists(ost/Alpha)': False,
#  'exists(이하/Noun)': False,
#  'exists(확/Noun)': False,
#  'exists(먼저/Noun)': False,
#  'exists(이/Josa)': False,
#  'exists(토/Noun)': False,
#  'exists(최고다/Noun)': False,
#  'exists(아름답다/Adjective)': False,
#  'exists(번째/Suffix)': False,
#  'exists(께/Josa)': False,
#  'exists(해주다/Verb)': False,
#  'exists(바라보다/Verb)': False,
#  'exists(들이다/Verb)': False,
#  'exists(다니다/Verb)': False,
#  'exists(효/Noun)': False,
#  'exists(개판/Noun)': False,
#  'exists(촬영/Noun)': False,
#  'exists(오빠/Suffix)': False,
#  'exists(돋보이다/Verb)': False,
#  'exists(명품/Noun)': False,
#  'exists(포인트/Noun)': False,
#  'exists(가끔/Noun)': False,
#  'exists(갖다/Verb)': False,
#  'exists(이며/Josa)': False,
#  'exists(초딩/Noun)': False,
#  'exists(에서도/Josa)': False,
#  'exists(까진/Josa)': False,
#  'exists(꽝/Noun)': False,
#  'exists(대화/Noun)': False,
#  'exists(우정/Noun)': False,
#  'exists(이제야/Noun)': False,
#  'exists(환상/Noun)': False,
#  'exists(밖에/Josa)': False,
#  'exists(만/Noun)': False,
#  'exists(현재/Noun)': False,
#  'exists(관계/Noun)': False,
#  'exists(명작/Noun)': False,
#  'exists(만들어지다/Verb)': False,
#  'exists(주말/Noun)': False,
#  'exists(부/Noun)': False,
#  'exists(그러나/Conjunction)': False,
#  'exists(까지도/Josa)': False,
#  'exists(갈다/Verb)': False,
#  'exists(로/Josa)': False,
#  'exists(그/Noun)': False,
#  'exists(병/Noun)': False,
#  'exists(강렬하다/Adjective)': False,
#  'exists(사진/Noun)': False,
#  'exists(뭐라다/Verb)': False,
#  'exists(시리즈/Noun)': False,
#  'exists(꿀잼/Noun)': False,
#  'exists(향/Noun)': False,
#  'exists(자신/Noun)': False,
#  'exists(아/Exclamation)': True,
#  'exists(섬세/Noun)': False,
#  'exists(형편/Noun)': False,
#  'exists(보아/Noun)': False,
#  'exists(태어나다/Verb)': False,
#  'exists(공부/Noun)': False,
#  'exists(깊이/Noun)': False,
#  'exists(성도/Noun)': False,
#  'exists(민망/Noun)': False,
#  'exists(음악/Noun)': False,
#  'exists(좋아하다/Adjective)': False,
#  'exists(ㅡㅡ/KoreanParticle)': False,
#  'exists(부끄럽다/Adjective)': False,
#  'exists(ㅠ/KoreanParticle)': False,
#  'exists(사건/Noun)': False,
#  'exists(뿐이다/Adjective)': False,
#  'exists(냐/Josa)': False,
#  'exists(지/Josa)': False,
#  'exists(해도/Noun)': False,
#  'exists(특히/Adverb)': False,
#  'exists(아이돌/Noun)': False,
#  'exists(해도/Josa)': False,
#  'exists(변하다/Adjective)': False,
#  'exists(지키다/Verb)': False,
#  'exists(실제/Noun)': False,
#  'exists(양심/Noun)': False,
#  'exists(원/Noun)': False,
#  'exists(이제/Noun)': False,
#  'exists(씩/Suffix)': False,
#  'exists(유머/Noun)': False,
#  'exists(본적/Noun)': False,
#  'exists(일상/Noun)': False,
#  'exists(여/Noun)': False,
#  'exists(은/Noun)': False,
#  'exists(대한/Noun)': False,
#  'exists(썩다/Verb)': False,
#  'exists(의심/Noun)': False,
#  'exists(터지다/Verb)': False,
#  'exists(딱하다/Adjective)': False,
#  'exists(살아가다/Verb)': False,
#  'exists(도안/Noun)': False,
#  'exists(건가/Noun)': False,
#  'exists(비극/Noun)': False,
#  'exists(아버지/Noun)': False,
#  'exists(그나마/Adverb)': False,
#  'exists(짝퉁/Noun)': False,
#  'exists(ㅎㅎ/KoreanParticle)': False,
#  'exists(갑/Noun)': False,
#  'exists(값/Noun)': False,
#  'exists(형님/Noun)': False,
#  'exists(낮다/Adjective)': False,
#  'exists(극/NounPrefix)': False,
#  'exists(특유/Noun)': False,
#  'exists(20/Number)': False,
#  'exists(없다/Adjective)': False,
#  'exists(생각/Noun)': False,
#  'exists(외계인/Noun)': False,
#  'exists(첫/Noun)': False,
#  'exists(남다/Verb)': False,
#  'exists(세다/Verb)': False,
#  'exists(이든/Josa)': False,
#  'exists(공포물/Noun)': False,
#  'exists(</Punctuation)': False,
#  'exists(만나다/Verb)': False,
#  'exists(..?/Punctuation)': False,
#  'exists(제작비/Noun)': False,
#  'exists(평가/Noun)': False,
#  'exists(드럽/Noun)': False,
#  'exists(희생/Noun)': False,
#  'exists(안다/Verb)': False,
#  'exists(길다/Adjective)': False,
#  'exists(영국/Noun)': False,
#  'exists(이니/Josa)': False,
#  'exists(분노/Noun)': False,
#  'exists(시선/Noun)': False,
#  'exists(그럭저럭/Noun)': False,
#  'exists(결정/Noun)': False,
#  'exists(눈빛/Noun)': False,
#  'exists(역겹다/Adjective)': False,
#  'exists(어린이/Noun)': False,
#  'exists(캐/Noun)': False,
#  'exists(감동/Noun)': False,
#  'exists(???/Punctuation)': False,
#  'exists(들다/Verb)': False,
#  'exists(따로/Adverb)': False,
#  'exists(통쾌/Noun)': False,
#  'exists(제작/Noun)': False,
#  'exists(더/Noun)': False,
#  'exists(네/Noun)': False,
#  'exists(세월/Noun)': False,
#  'exists(의리/Noun)': False,
#  'exists(극/Suffix)': False,
#  'exists(로서/Noun)': False,
#  'exists(ㅅ/KoreanParticle)': False,
#  'exists(끝나다/Verb)': False,
#  'exists(빛/Noun)': False,
#  'exists(틀다/Verb)': False,
#  'exists(겁니다/Verb)': False,
#  'exists(처/Noun)': False,
#  'exists(살/Noun)': False,
#  'exists(삼/Noun)': False,
#  'exists(흑인/Noun)': False,
#  'exists(명/Noun)': False,
#  'exists(허다/Verb)': False,
#  'exists(예쁘다/Adjective)': False,
#  'exists(메시지/Noun)': False,
#  'exists(조합/Noun)': False,
#  'exists(않다/Verb)': False,
#  'exists(변태/Noun)': False,
#  'exists(따뜻하다/Adjective)': False,
#  'exists(어색하다/Adjective)': False,
#  'exists(주/Noun)': False,
#  'exists(겨우/Noun)': False,
#  'exists(과거/Noun)': False,
#  'exists(채널/Noun)': False,
#  'exists(답답하다/Adjective)': False,
#  'exists(떼다/Verb)': False,
#  'exists(이번/Noun)': False,
#  'exists(몇/Noun)': False,
#  'exists(끝내다/Verb)': False,
#  'exists(와의/Josa)': False,
#  'exists(작다/Adjective)': False,
#  'exists(안타깝다/Adjective)': False,
#  'exists(보라/Noun)': False,
#  'exists(아저씨/Noun)': False,
#  'exists(소소하다/Adjective)': False,
#  'exists(정말로/Adverb)': False,
#  'exists(영화/Noun)': False,
#  'exists(성하/Noun)': False,
#  'exists(난/Josa)': False,
#  'exists(차이/Noun)': False,
#  'exists(특이하다/Adjective)': False,
#  'exists(투자/Noun)': False,
#  'exists(러닝/Noun)': False,
#  'exists(동생/Noun)': False,
#  'exists(대하다/Verb)': False,
#  'exists(맘/Noun)': False,
#  'exists(어처구니/Noun)': False,
#  'exists(놈/Noun)': False,
#  'exists(암/Noun)': False,
#  'exists(뭐임/Noun)': False,
#  'exists(놓치다/Verb)': False,
#  'exists(함/Noun)': False,
#  'exists(그린/Noun)': False,
#  'exists(2/Number)': False,
#  'exists(것/Noun)': False,
#  'exists(코/Noun)': False,
#  'exists(한테/Josa)': False,
#  'exists(수준/Noun)': False,
#  'exists(날다/Verb)': False,
#  'exists(자체/Noun)': False,
#  'exists(데리/Noun)': False,
#  'exists(부모님/Noun)': False,
#  'exists(설마/Noun)': False,
#  'exists(는걸/Noun)': False,
#  'exists(편견/Noun)': False,
#  'exists(말/Noun)': False,
#  'exists(낚였/Noun)': False,
#  'exists(게임/Noun)': False,
#  'exists(글/Noun)': False,
#  'exists(생생/Noun)': False,
#  'exists(표현/Noun)': False,
#  'exists(햇/Noun)': False,
#  'exists(미드/Noun)': False,
#  'exists(떠나다/Verb)': False,
#  'exists(진정/Noun)': False,
#  'exists(행동/Noun)': False,
#  'exists(기회/Noun)': False,
#  'exists(티비/Noun)': False,
#  'exists(쓸다/Verb)': False,
#  'exists(옛날/Noun)': False,
#  'exists(♥/Foreign)': False,
#  'exists(//Punctuation)': False,
#  'exists(희망/Noun)': False,
#  'exists(중반/Noun)': False,
#  'exists(완전/Noun)': False,
#  'exists(대작/Noun)': False,
#  'exists(들/Suffix)': False,
#  'exists(연출/Noun)': False,
#  'exists(>/Punctuation)': False,
#  'exists(삶/Noun)': False,
#  'exists(그래도/Adverb)': False,
#  'exists(에나/Josa)': False,
#  'exists(으로도/Josa)': False,
#  'exists(반복/Noun)': False,
#  'exists(스/Noun)': False,
#  'exists(때/Noun)': False,
#  'exists(완벽하다/Adjective)': False,
#  'exists(님/Suffix)': False,
#  'exists(자극/Noun)': False,
#  'exists(등장인물/Noun)': False,
#  'exists(대가/Noun)': False,
#  'exists(일어나다/Verb)': False,
#  'exists(이랑/Josa)': False,
#  'exists(b/Alpha)': False,
#  'exists(거슬리다/Adjective)': False,
#  'exists(수도/Noun)': False,
#  'exists(재다/Verb)': False,
#  'exists(정치/Noun)': False,
#  'exists(영화인/Noun)': False,
#  'exists(사이/Noun)': False,
#  'exists(으/Adverb)': False,
#  'exists(심심하다/Adjective)': False,
#  'exists(한번/Noun)': False,
#  'exists(생활/Noun)': False,
#  'exists(일품/Noun)': False,
#  'exists(엇/VerbPrefix)': False,
#  'exists(함께/Adverb)': False,
#  'exists(상/Suffix)': False,
#  'exists(딸/Noun)': False,
#  'exists(좀/Noun)': False,
#  'exists(지난/Noun)': False,
#  'exists(싸다/Verb)': False,
#  'exists(./Punctuation)': False,
#  'exists(솔직하다/Adjective)': False,
#  'exists(풋풋/Noun)': False,
#  'exists(졸다/Verb)': False,
#  'exists(글쎄/Noun)': False,
#  'exists(호구/Noun)': False,
#  'exists(라이/Noun)': False,
#  'exists(볼때/Noun)': False,
#  'exists(지는/Josa)': False,
#  'exists(보다는/Josa)': False,
#  'exists(씨/Suffix)': False,
#  'exists(만큼/Noun)': False,
#  'exists(돋다/Adjective)': False,
#  'exists(준/Noun)': False,
#  'exists(라인/Noun)': False,
#  'exists(따라가다/Verb)': False,
#  'exists(심각하다/Adjective)': False,
#  'exists(잠/Noun)': False,
#  'exists(바로/Noun)': False,
#  'exists(쓰레기/Noun)': False,
#  'exists(와우/Noun)': False,
#  'exists(피해자/Noun)': False,
#  'exists(아련하다/Adjective)': False,
#  'exists(관/Noun)': False,
#  'exists(우/Adverb)': False,
#  'exists(요즘/Noun)': False,
#  'exists(ㅇㅇ/KoreanParticle)': False,
#  'exists(선물/Noun)': False,
#  'exists(드리다/Verb)': False,
#  'exists(여행/Noun)': False,
#  'exists(네/Josa)': False,
#  'exists(젊다/Adjective)': False,
#  'exists(못/Noun)': False,
#  'exists(자/Suffix)': False,
#  'exists(뛰어나다/Adjective)': False,
#  'exists(난/Noun)': False,
#  'exists(열정/Noun)': False,
#  'exists(허무/Noun)': False,
#  'exists(느낌/Noun)': False,
#  'exists(대사/Noun)': False,
#  'exists(짓/Noun)': False,
#  'exists(찍다/Verb)': False,
#  'exists(얼굴/Noun)': False,
#  'exists(틀리다/Verb)': False,
#  'exists(동물/Noun)': False,
#  'exists(대의/Noun)': False,
#  'exists(잠깐/Noun)': False,
#  'exists(한국영/Noun)': False,
#  'exists(초등학생/Noun)': False,
#  'exists(역사/Noun)': False,
#  'exists(망작/Noun)': False,
#  'exists(조절/Noun)': False,
#  'exists(에는/Josa)': False,
#  'exists(마무리/Noun)': False,
#  'exists(이미/Adverb)': False,
#  'exists(년/Noun)': False,
#  'exists(동화/Noun)': False,
#  'exists(매우/Noun)': False,
#  'exists(남편/Noun)': False,
#  'exists(화/Noun)': False,
#  'exists(라고/Josa)': False,
#  'exists(......./Punctuation)': False,
#  'exists(커플/Noun)': False,
#  'exists(류/Noun)': False,
#  'exists(밑/Noun)': False,
#  'exists(제/Noun)': False,
#  'exists(연예인/Noun)': False,
#  'exists(보이다/Verb)': False,
#  'exists(살아나다/Verb)': False,
#  'exists(히어로/Noun)': False,
#  'exists(쏘다/Verb)': False,
#  'exists(감/Noun)': False,
#  'exists(본영/Noun)': False,
#  'exists(흥미진진/Noun)': False,
#  'exists(쯤/Suffix)': False,
#  'exists(7/Number)': False,
#  'exists(아침/Noun)': False,
#  'exists((?)/Punctuation)': False,
#  'exists(웬만하다/Adjective)': False,
#  'exists(대체/Noun)': False,
#  'exists(이야/Josa)': False,
#  'exists(낫다/Verb)': False,
#  'exists(전혀/Noun)': False,
#  'exists(싸우다/Verb)': False,
#  'exists(감상/Noun)': False,
#  'exists(속편/Noun)': False,
#  'exists(싶다/Verb)': False,
#  'exists(후/Noun)': False,
#  'exists(무협/Noun)': False,
#  'exists(기술/Noun)': False,
#  'exists(줄/Noun)': False,
#  'exists(배우/Noun)': False,
#  'exists(너/Noun)': False,
#  'exists(어른/Noun)': False,
#  'exists(점/Noun)': False,
#  'exists(내생/Noun)': False,
#  'exists(맞추다/Verb)': False,
#  'exists(나중/Noun)': False,
#  'exists(로만/Noun)': False,
#  'exists(분/Noun)': False,
#  'exists(던지다/Verb)': False,
#  'exists(저런/Noun)': False,
#  'exists(잘못/Noun)': False,
#  'exists(ㄷㄷ/KoreanParticle)': False,
#  'exists(시기/Noun)': False,
#  'exists(걸/Noun)': False,
#  'exists(질/Noun)': False,
#  'exists(취향/Noun)': False,
#  'exists(해/Noun)': False,
#  'exists(변화/Noun)': False,
#  'exists(마음/Noun)': False,
#  'exists(지루/Noun)': False,
#  'exists(설명/Noun)': False,
#  'exists(깊다/Adjective)': False,
#  'exists(마다/Josa)': False,
#  'exists(계속/Noun)': False,
#  'exists(당시/Noun)': False,
#  'exists(맨/Noun)': False,
#  'exists(시시/Noun)': False,
#  'exists(복수/Noun)': False,
#  'exists(거/Noun)': False,
#  'exists(처음/Noun)': False,
#  'exists(70/Number)': False,
#  'exists(놓다/Verb)': False,
#  'exists(전쟁/Noun)': False,
#  'exists(못/VerbPrefix)': False,
#  'exists(얼마/Noun)': False,
#  'exists(전작/Noun)': False,
#  'exists("""/Punctuation)': False,
#  'exists(티/Noun)': False,
#  'exists(의외로/Adverb)': False,
#  'exists(답/Noun)': False,
#  'exists(국내/Noun)': False,
#  'exists(댓글/Noun)': False,
#  'exists(극장판/Noun)': False,
#  'exists(많이/Adverb)': False,
#  'exists(니까/Josa)': False,
#  'exists(고민/Noun)': False,
#  'exists(아쉬움/Noun)': False,
#  'exists(년도/Noun)': False,
#  'exists(억지로/Noun)': False,
#  'exists(불가/Noun)': False,
#  'exists(예요/Josa)': False,
#  'exists(그래서/Adverb)': False,
#  'exists(편집/Noun)': False,
#  'exists(좋아지다/Adjective)': False,
#  'exists(밉다/Adjective)': False,
#  'exists(력/Suffix)': False,
#  'exists(괴물/Noun)': False,
#  'exists(탄탄/Noun)': False,
#  'exists(재밌다/Adjective)': False,
#  'exists(엉망/Noun)': False,
#  'exists(../Punctuation)': True,
#  'exists(롭고/Josa)': False,
#  'exists(뛰어넘다/Verb)': False,
#  'exists(강추/Noun)': False,
#  'exists(대/Suffix)': False,
#  'exists(조용하다/Adjective)': False,
#  'exists(전개/Noun)': False,
#  'exists(해내다/Verb)': False,
#  'exists(등등/Noun)': False,
#  'exists(빌리다/Verb)': False,
#  'exists(조차/Josa)': False,
#  'exists(라서/Josa)': False,
#  'exists(여주/Noun)': False,
#  'exists(랄/Noun)': False,
#  'exists(대로/Josa)': False,
#  'exists(예/Noun)': False,
#  'exists(연기력/Noun)': False,
#  'exists(자살/Noun)': False,
#  'exists(독특하다/Adjective)': False,
#  'exists(오그/Noun)': False,
#  'exists(볼/Noun)': False,
#  'exists(허세/Noun)': False,
#  'exists(모/Noun)': False,
#  'exists(그렇게/Adverb)': False,
#  'exists(낚/Noun)': False,
#  'exists(늘/Noun)': False,
#  'exists(단지/Noun)': False,
#  'exists(귀신/Noun)': False,
#  'exists(참고/Noun)': False,
#  'exists(정체/Noun)': False,
#  'exists(채/Noun)': False,
#  'exists(SF/Alpha)': False,
#  'exists(여서/Josa)': False,
#  'exists(15/Number)': False,
#  'exists(사수/Noun)': False,
#  'exists(일본/Noun)': False,
#  'exists(느와르/Noun)': False,
#  'exists(사/Noun)': False,
#  'exists(이리/Adverb)': False,
#  'exists(심하다/Adjective)': False,
#  'exists(멀다/Adjective)': False,
#  'exists(움/Noun)': False,
#  'exists(재미없다/Adjective)': False,
#  'exists(주기도/Noun)': False,
#  'exists(멍청하다/Adjective)': False,
#  'exists(견자단/Noun)': False,
#  'exists(선택/Noun)': False,
#  'exists(한마디/Noun)': False,
#  'exists(비주/Noun)': False,
#  'exists(감성/Noun)': False,
#  'exists(때리다/Verb)': False,
#  'exists(끼다/Verb)': False,
#  'exists(????/Punctuation)': False,
#  'exists(막/Noun)': False,
#  'exists(관심/Noun)': False,
#  'exists(....../Punctuation)': False,
#  'exists(헐리웃/Noun)': False,
#  'exists(채우다/Verb)': False,
#  'exists(막장드라마/Noun)': False,
#  'exists(웃다/Verb)': False,
#  'exists(꾸다/Verb)': False,
#  'exists(잇다/Verb)': False,
#  'exists(주의/Noun)': False,
#  'exists(깔끔하다/Adjective)': False,
#  'exists(머리/Noun)': False,
#  'exists(감사/Noun)': False,
#  'exists(살인/Noun)': False,
#  'exists(꿈/Noun)': False,
#  'exists(멋지다/Adjective)': False,
#  'exists(뽑다/Verb)': False,
#  'exists(유쾌하/Noun)': False,
#  'exists(주인공/Noun)': False,
#  'exists()/Punctuation)': False,
#  'exists(듬/Noun)': False,
#  'exists(적/Noun)': False,
#  'exists(밀리다/Verb)': False,
#  'exists(간/Suffix)': False,
#  'exists(카메라/Noun)': False,
#  'exists(또/Noun)': False,
#  'exists(범죄/Noun)': False,
#  'exists(개/Suffix)': False,
#  'exists(말고/Josa)': False,
#  'exists(굿굿/Noun)': False,
#  'exists(아프다/Adjective)': False,
#  'exists(식상하다/Adjective)': False,
#  'exists(가깝다/Adjective)': False,
#  'exists(등장/Noun)': False,
#  'exists(지다/Verb)': False,
#  'exists(코난/Noun)': False,
#  'exists(ㅜ/KoreanParticle)': False,
#  'exists(흔하다/Adjective)': False,
#  'exists(홍보/Noun)': False,
#  'exists(의도/Noun)': False,
#  'exists(깨다/Verb)': False,
#  'exists(이라고/Josa)': False,
#  'exists(번/Noun)': False,
#  'exists(엄마/Noun)': False,
#  'exists(본방/Noun)': False,
#  'exists(오빠/Noun)': False,
#  'exists(노출/Noun)': False,
#  'exists(크리스마스/Noun)': False,
#  'exists(순간/Noun)': False,
#  'exists(내내/Noun)': False,
#  'exists(나머지/Noun)': False,
#  'exists(ㅡ/KoreanParticle)': False,
#  'exists(극장/Noun)': False,
#  'exists(돌다/Verb)': False,
#  'exists(시작/Noun)': False,
#  'exists(홍콩/Noun)': False,
#  'exists(만큼은/Josa)': False,
#  'exists(받다/Verb)': False,
#  'exists(아줌마/Noun)': False,
#  'exists(끝/Noun)': False,
#  'exists(한/Determiner)': False,
#  'exists(갑자기/Noun)': False,
#  'exists(쓰다/Verb)': False,
#  'exists(싸구려/Noun)': False,
#  'exists(스케일/Noun)': False,
#  'exists(베스트/Noun)': False,
#  'exists(...?/Punctuation)': False,
#  'exists(무척/Noun)': False,
#  'exists(랑/Josa)': False,
#  'exists(""""/Punctuation)': False,
#  'exists(후회/Noun)': False,
#  'exists(안/Noun)': False,
#  'exists(~~/Punctuation)': False,
#  'exists(+/Punctuation)': False,
#  'exists(바뀌다/Verb)': False,
#  'exists(공포영화/Noun)': False,
#  'exists(되다/Verb)': False,
#  'exists(노잼/Noun)': False,
#  'exists(미래/Noun)': False,
#  ...}

# %%
train_xy = []
test_xy = []

train_docs = train_docs[:30000]

for _ in range(len(train_docs)):
    d, c = train_docs.pop(0)
    train_xy.append((term_exists(d), c))

for _ in range(len(test_docs)):
    d, c = test_docs.pop(0)
    test_xy.append((term_exists(d), c))

# %%
classifier = nltk.NaiveBayesClassifier.train(train_xy)
print(nltk.classify.accuracy(classifier, test_xy))

classifier.show_most_informative_features(10)
# Out:
# 0.81282
# Most Informative Features
#          exists(최악/Noun) = True                0 : 1      =     50.5 : 1.0
#          exists(낭비/Noun) = True                0 : 1      =     35.2 : 1.0
#           exists(똥/Noun) = True                0 : 1      =     34.1 : 1.0
#          exists(노잼/Noun) = True                0 : 1      =     28.0 : 1.0
#         exists(최고다/Noun) = True                1 : 0      =     26.0 : 1.0
#          exists(졸작/Noun) = True                0 : 1      =     25.7 : 1.0
#          exists(반개/Noun) = True                0 : 1      =     25.5 : 1.0
#        exists(♥/Foreign) = True                1 : 0      =     24.0 : 1.0
#         exists(찡/Adverb) = True                1 : 0      =     23.1 : 1.0
#           exists(굿/Noun) = True                1 : 0      =     22.7 : 1.0

# %%
from collections import namedtuple
TaggedDocument = namedtuple('TaggedDocument', 'words tags')
# 여기서는 15만개 training documents 전부 사용함
tagged_train_docs = [TaggedDocument(d, [c]) for d, c in train_docs]
tagged_test_docs = [TaggedDocument(d, [c]) for d, c in test_docs]

# %%
from gensim.models import doc2vec
# 사전 구축
doc_vectorizer = doc2vec.Doc2Vec(size=300, alpha=0.025, min_alpha=0.025, seed=1234) #size,epoch 등 변경해보기
doc_vectorizer.build_vocab(tagged_train_docs)
# Train document vectors!
for epoch in range(10):
    doc_vectorizer.train(tagged_train_docs)
    doc_vectorizer.alpha -= 0.002  # decrease the learning rate
    doc_vectorizer.min_alpha = doc_vectorizer.alpha  # fix the learning rate, no decay

# %%
pprint(doc_vectorizer.most_similar('공포/Noun'))
# Out:
# [('공포영화/Noun', 0.4244290888309479),
#  ('호러/Noun', 0.3459432125091553),
#  ('서스펜스/Noun', 0.3282715678215027),
#  ('긴박/Noun', 0.29170575737953186),
#  ('미스터리/Noun', 0.28643351793289185),
#  ('스릴러/Noun', 0.26772546768188477),
#  ('무섭다/Adjective', 0.2608919143676758),
#  ('반전/Noun', 0.25883162021636963),
#  ('귀신/Noun', 0.2580486536026001),
#  ('당혹/Noun', 0.2504921853542328)]

# %%
pprint(doc_vectorizer.most_similar('ㅋㅋ/KoreanParticle'))
# Out:
# [('ㅋㅋㄱ/KoreanParticle', 0.33676469326019287),
#  ('ㅋ/KoreanParticle', 0.3310341238975525),
#  ('!!!!!!!!!!!!!!/Punctuation', 0.2943721413612366),
#  ('농부/Noun', 0.2838119864463806),
#  ('ㅉㅉ/KoreanParticle', 0.27554744482040405),
#  ('^^^/Punctuation', 0.272133469581604),
#  ('ㅎㅎ/KoreanParticle', 0.26229777932167053),
#  ('-_-;/Punctuation', 0.2622581124305725),
#  ('송재림/Noun', 0.2533813714981079),
#  ('박형식/Noun', 0.25229310989379883)]

# %%
pprint(doc_vectorizer.most_similar(positive=['여자/Noun', '왕/Noun'], negative=['남자/Noun']))
# Out:
# [('압/Noun', 0.2870830297470093),
#  ('증인/Noun', 0.23717403411865234),
#  ('백치/Noun', 0.23699885606765747),
#  ('패전/Noun', 0.23230470716953278),
#  ('김삼순/Noun', 0.23064997792243958),
#  ('거두다/Verb', 0.22163476049900055),
#  ('전도연/Noun', 0.21829411387443542),
#  ('궁합/Noun', 0.21358992159366608),
#  ('총집/Noun', 0.21237078309059143),
#  ('베일/Noun', 0.21168667078018188)]

# %%
text.concordance('왕/Noun', lines=10)
# Out:
# Displaying 10 of 145 matches:
# Josa 로맨스/Noun 냐/Josa ,,/Punctuation 왕/Noun 짜증/Noun ...../Punctuation 아주/Noun 전
# /Noun 함/Noun ../Punctuation 결말/Noun 왕/Noun 실망/Noun 임/Noun 전작/Noun 에/Josa 비/Nou
# nction 얼굴/Noun 만/Josa 예쁘다/Adjective 왕/Noun 되다/Verb 맞다/Verb 드라마/Noun 라도/Josa 도덕
# /Noun 스릴러/Noun 임/Noun ?/Punctuation 왕/Noun 실망/Noun ./Punctuation 연기/Noun 대본/No
# b 금/Noun 사인방/Noun ㅠㅠ/KoreanParticle 왕/Noun 잼/Noun 없다/Adjective ./Punctuation 정
# osa 서유기/Noun 보다/Josa 희극/Noun 지/Josa 왕/Noun 이/Josa 더/Noun 최고/Noun 라/Josa 생각/Nou
# 접/Noun 한/Josa 걸작/Noun ./Punctuation 왕/Noun ,/Punctuation 너무/Noun 감동/Noun 적/Suf
# Josa 온/Noun 거/Noun 처럼/Noun 제나라/Noun 왕/Noun 과/Josa 군사/Noun 들/Suffix 을/Josa 속이다/
# 다/Verb ./Punctuation 기대하다/Adjective 왕/Noun 지루/Noun .../Punctuation 제니퍼/Noun 틸리
# tive 움/Noun 짜증/Noun .../Punctuation 왕/Noun 짜증/Noun ../Punctuation 사람/Noun 마다/J

# %%
train_x = [doc_vectorizer.infer_vector(doc.words) for doc in tagged_train_docs]
train_y = [doc.tags[0] for doc in tagged_train_docs]

test_x = [doc_vectorizer.infer_vector(doc.words) for doc in tagged_test_docs]
test_y = [doc.tags[0] for doc in tagged_test_docs]

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(random_state=0)
classifier.fit(train_x, train_y)
classifier.score(test_x, test_y)
# Out:
# 0.63173999999999997

# %% [markdown]
# ---
#
# # 변형

# %%
train_xy[0]
# Out:
# ({'exists(든/Josa)': False,
#   'exists(소장/Noun)': False,
#   'exists(수고/Noun)': False,
#   'exists(힐링/Noun)': False,
#   'exists(방식/Noun)': False,
#   'exists(성룡/Noun)': False,
#   'exists(인지/Josa)': False,
#   'exists(조잡/Noun)': False,
#   'exists(예능/Noun)': False,
#   'exists(시키다/Verb)': False,
#   'exists(굉장하다/Adjective)': False,
#   'exists(등/Noun)': False,
#   'exists(그렇다고/Conjunction)': False,
#   'exists(남/Noun)': False,
#   'exists(보단/Josa)': False,
#   'exists(CG/Alpha)': False,
#   'exists(가수/Noun)': False,
#   'exists(ㅠㅜ/KoreanParticle)': False,
#   'exists(야동/Noun)': False,
#   'exists(괜히/Adverb)': False,
#   'exists(임/Noun)': False,
#   'exists(시나리오/Noun)': False,
#   'exists(끼리/Noun)': False,
#   'exists(!!/Punctuation)': False,
#   'exists(독립영화/Noun)': False,
#   'exists(D/Alpha)': False,
#   'exists(이라니/Josa)': False,
#   'exists(이해/Noun)': False,
#   'exists(궁금하다/Adjective)': False,
#   'exists(형사/Noun)': False,
#   'exists(장/Suffix)': False,
#   'exists(스릴/Noun)': False,
#   'exists(별점/Noun)': False,
#   'exists(지루하다/Adjective)': False,
#   'exists(여/Josa)': False,
#   'exists(유쾌/Noun)': False,
#   'exists(ㅉㅉ/KoreanParticle)': False,
#   'exists(9/Number)': False,
#   'exists(착하다/Adjective)': False,
#   'exists(잊다/Verb)': False,
#   'exists(자기/Noun)': False,
#   'exists(둘/Noun)': False,
#   'exists(매다/Verb)': False,
#   'exists(위해/Noun)': False,
#   'exists(설레다/Adjective)': False,
#   'exists(완성/Noun)': False,
#   'exists(시간/Noun)': False,
#   'exists(굿/Noun)': False,
#   'exists(남녀/Noun)': False,
#   'exists(행복/Noun)': False,
#   'exists(이자/Noun)': False,
#   'exists(빨리/Adverb)': False,
#   'exists(주연/Noun)': False,
#   'exists(이렇게/Adverb)': False,
#   'exists(훨씬/Adverb)': False,
#   'exists(아주/Noun)': False,
#   'exists(년대/Noun)': False,
#   'exists(들어가다/Verb)': False,
#   'exists(결말/Noun)': False,
#   'exists(화/Suffix)': False,
#   'exists(대부분/Noun)': False,
#   'exists(최강/Noun)': False,
#   'exists(화려하다/Adjective)': False,
#   'exists(생애/Noun)': False,
#   'exists(이래서/Josa)': False,
#   'exists(평론가/Noun)': False,
#   'exists(,,,/Punctuation)': False,
#   'exists(그리고/Conjunction)': False,
#   'exists(배/Noun)': False,
#   'exists(그다지/Noun)': False,
#   'exists(프로그램/Noun)': False,
#   'exists(청소년/Noun)': False,
#   'exists(좋다/Adjective)': False,
#   'exists(두/Josa)': False,
#   'exists(언제/Noun)': False,
#   'exists(이보/Noun)': False,
#   'exists(보기/Noun)': False,
#   'exists(죽이다/Verb)': False,
#   'exists(으로/Josa)': False,
#   'exists(마지막/Noun)': False,
#   'exists(문제/Noun)': False,
#   'exists(까지는/Josa)': False,
#   'exists(떠오르다/Verb)': False,
#   'exists(손/Noun)': False,
#   'exists(새/Noun)': False,
#   'exists(후반/Noun)': False,
#   'exists(메세지/Noun)': False,
#   'exists(방영/Noun)': False,
#   'exists(흥미/Noun)': False,
#   'exists(초반/Noun)': False,
#   'exists(기발/Noun)': False,
#   'exists(걸리다/Verb)': False,
#   'exists(책/Noun)': False,
#   'exists(아쉽다/Adjective)': False,
#   'exists(내/Noun)': False,
#   'exists(드림/Noun)': False,
#   'exists(걸다/Verb)': False,
#   'exists(몇/NounPrefix)': False,
#   'exists(덕/Noun)': False,
#   'exists(기분/Noun)': False,
#   'exists(미치다/Adjective)': False,
#   'exists(영환/Noun)': False,
#   'exists(.../Punctuation)': False,
#   'exists(전부/Noun)': False,
#   'exists(잡다/Verb)': False,
#   'exists(확인/Noun)': False,
#   'exists(어디/Noun)': False,
#   'exists(가보다/Verb)': False,
#   'exists(즐기다/Verb)': False,
#   'exists(광고/Noun)': False,
#   'exists(영상/Noun)': False,
#   'exists(용도/Noun)': False,
#   'exists(영혼/Noun)': False,
#   'exists(파다/Verb)': False,
#   'exists(없이/Adverb)': False,
#   'exists(스릴러/Noun)': False,
#   'exists(나름/Noun)': False,
#   'exists(되게/Adverb)': False,
#   'exists(할머니/Noun)': False,
#   'exists(~~~~/Punctuation)': False,
#   'exists(작/Noun)': False,
#   'exists(최/Noun)': False,
#   'exists(전설/Noun)': False,
#   'exists(상황/Noun)': False,
#   'exists(뮤지컬/Noun)': False,
#   'exists(감흥/Noun)': False,
#   'exists(황당/Noun)': False,
#   'exists(여배우/Noun)': False,
#   'exists(치밀/Noun)': False,
#   'exists(그리다/Verb)': False,
#   'exists(추억/Noun)': False,
#   'exists(첨/Adverb)': False,
#   'exists(어디서/Adverb)': False,
#   'exists(과/Josa)': False,
#   'exists(형제/Noun)': False,
#   'exists(여러/Noun)': False,
#   'exists(!!!!/Punctuation)': False,
#   'exists(tv/Alpha)': False,
#   'exists(반성/Noun)': False,
#   'exists(얼/Noun)': False,
#   'exists(진/Noun)': False,
#   'exists(평생/Noun)': False,
#   'exists(오히려/Noun)': False,
#   'exists(다큐멘터리/Noun)': False,
#   'exists(아무렇다/Adjective)': False,
#   'exists(어떻다/Adjective)': False,
#   'exists(성은/Noun)': False,
#   'exists(줍다/Verb)': False,
#   'exists(관객/Noun)': False,
#   'exists((/Punctuation)': False,
#   'exists(감히/Noun)': False,
#   'exists(이야기/Noun)': False,
#   'exists(급/Suffix)': False,
#   'exists(효과/Noun)': False,
#   'exists(구/Noun)': False,
#   'exists(감탄/Noun)': False,
#   'exists(다시/Noun)': False,
#   'exists(손발/Noun)': False,
#   'exists(재/Noun)': False,
#   'exists(참다/Verb)': False,
#   'exists(뻔하다/Adjective)': False,
#   'exists(계/Suffix)': False,
#   'exists(조금/Noun)': False,
#   'exists(보이/Noun)': False,
#   'exists(연기/Noun)': False,
#   'exists(알다/Verb)': False,
#   'exists(의/Noun)': False,
#   'exists(90/Number)': False,
#   'exists(쵝오/Noun)': False,
#   'exists(발견/Noun)': False,
#   'exists(기억나다/Verb)': False,
#   'exists(막히다/Verb)': False,
#   'exists(스러운/Josa)': False,
#   'exists(처럼/Noun)': False,
#   'exists(최고/Noun)': False,
#   'exists(신경/Noun)': False,
#   'exists(국가/Noun)': False,
#   'exists(~!!/Punctuation)': False,
#   'exists(잘/VerbPrefix)': False,
#   'exists(조작/Noun)': False,
#   'exists(때우다/Adjective)': False,
#   'exists(비교/Noun)': False,
#   'exists(섹시하다/Adjective)': False,
#   'exists(쩝/Adverb)': False,
#   'exists(식/Noun)': False,
#   'exists(역대/Noun)': False,
#   'exists(결론/Noun)': False,
#   'exists(체/Noun)': False,
#   'exists(의미/Noun)': False,
#   'exists(그대로/Noun)': False,
#   'exists(개인/Noun)': False,
#   'exists(좀비/Noun)': False,
#   'exists(끼/Noun)': False,
#   'exists(군대/Noun)': False,
#   'exists(끌다/Verb)': False,
#   'exists(범인/Noun)': False,
#   'exists(학교/Noun)': False,
#   'exists(애/Noun)': False,
#   'exists(막장/Noun)': False,
#   'exists(정서/Noun)': False,
#   'exists(다행/Noun)': False,
#   'exists(부터/Josa)': False,
#   'exists(뿐/Suffix)': False,
#   'exists(머/Noun)': False,
#   'exists(돌아가다/Verb)': False,
#   'exists(개뿔/Noun)': False,
#   'exists(용/Noun)': False,
#   'exists(개막/Noun)': False,
#   'exists(교육/Noun)': False,
#   'exists(만이/Josa)': False,
#   'exists(멋있다/Adjective)': False,
#   'exists(낳다/Verb)': False,
#   'exists(기다리다/Verb)': False,
#   'exists(아/Josa)': False,
#   'exists(거인/Noun)': False,
#   'exists(짜증/Noun)': True,
#   'exists(반전/Noun)': False,
#   'exists(대다/Verb)': False,
#   'exists(제대로/Noun)': False,
#   'exists(뭔가/Noun)': False,
#   'exists("""""""/Punctuation)': False,
#   'exists(제로/Noun)': False,
#   'exists(이연걸/Noun)': False,
#   'exists(만큼/Josa)': False,
#   'exists(물/Noun)': False,
#   'exists(욕/Noun)': False,
#   'exists(전문가/Noun)': False,
#   'exists(모자라다/Verb)': False,
#   'exists(불쾌/Noun)': False,
#   'exists(린다/Noun)': False,
#   'exists(에/Josa)': False,
#   'exists(무시/Noun)': False,
#   'exists(순수하다/Adjective)': False,
#   'exists(찾아보다/Verb)': False,
#   'exists(같다/Adjective)': False,
#   'exists(감다/Verb)': False,
#   'exists(연애/Noun)': False,
#   'exists(하니/Noun)': False,
#   'exists(기르다/Verb)': False,
#   'exists(신선하다/Adjective)': False,
#   'exists(이라도/Josa)': False,
#   'exists(내용/Noun)': False,
#   'exists(꺼/Suffix)': False,
#   'exists(바라다/Verb)': False,
#   'exists(요소/Noun)': False,
#   'exists(학생/Noun)': False,
#   'exists(1/Number)': False,
#   'exists(갈수록/Noun)': False,
#   'exists(다운/Noun)': False,
#   'exists(묘/Noun)': False,
#   'exists(으로써/Josa)': False,
#   'exists(단/Noun)': False,
#   'exists(신다/Verb)': False,
#   'exists(질리/Noun)': False,
#   'exists(틈/Noun)': False,
#   'exists(으론/Josa)': False,
#   'exists(세번/Noun)': False,
#   'exists(연결/Noun)': False,
#   'exists(다하다/Verb)': False,
#   'exists(촌스럽다/Adjective)': False,
#   'exists(포르노/Noun)': False,
#   'exists(인가/Josa)': False,
#   'exists(두다/Verb)': False,
#   'exists(너무/Noun)': False,
#   'exists(점주/Noun)': False,
#   'exists(케이블/Noun)': False,
#   'exists(남아/Noun)': False,
#   'exists(그걸/Adverb)': False,
#   'exists(다/Josa)': False,
#   'exists(노/Noun)': False,
#   'exists(읽다/Verb)': False,
#   'exists(소설/Noun)': False,
#   'exists(하다/Verb)': False,
#   'exists(;;;/Punctuation)': False,
#   'exists(기세/Noun)': False,
#   'exists(영어/Noun)': False,
#   'exists(폭력/Noun)': False,
#   'exists(니/Noun)': False,
#   'exists(혼자/Noun)': False,
#   'exists(봣/Noun)': False,
#   'exists(정도/Noun)': False,
#   'exists(내/Determiner)': False,
#   'exists(만/Suffix)': False,
#   'exists(하나로/Noun)': False,
#   'exists(파/Noun)': False,
#   'exists(잔/Noun)': False,
#   'exists(리얼/Noun)': False,
#   'exists(&/Punctuation)': False,
#   'exists(집/Noun)': False,
#   'exists(적절하다/Adjective)': False,
#   'exists(달다/Verb)': False,
#   'exists(나/Noun)': False,
#   'exists(으로는/Josa)': False,
#   'exists(까지/Noun)': False,
#   'exists(빠지다/Verb)': False,
#   'exists(이라서/Josa)': False,
#   'exists(..../Punctuation)': False,
#   'exists(무언가/Noun)': False,
#   'exists(중국/Noun)': False,
#   'exists(코드/Noun)': False,
#   'exists(애기/Noun)': False,
#   'exists(부터/Noun)': False,
#   'exists(많다/Adjective)': False,
#   'exists(중요하다/Adjective)': False,
#   'exists(캐스팅/Noun)': False,
#   'exists(라면/Noun)': False,
#   'exists(빵/Noun)': False,
#   'exists(있다/Adjective)': False,
#   'exists(개봉/Noun)': False,
#   'exists(사다/Verb)': False,
#   'exists(당하다/Adjective)': False,
#   'exists(분명하다/Adjective)': False,
#   'exists(다/Adverb)': False,
#   'exists(죽음/Noun)': False,
#   'exists(주기/Noun)': False,
#   'exists(만/Josa)': False,
#   'exists(^/Punctuation)': False,
#   'exists(감정/Noun)': False,
#   'exists(판타지/Noun)': False,
#   'exists(,./Punctuation)': False,
#   'exists(보/Noun)': False,
#   'exists(약하다/Adjective)': False,
#   'exists(리즈/Noun)': False,
#   'exists(숨기다/Verb)': False,
#   'exists(애니/Noun)': False,
#   'exists(실망/Noun)': False,
#   'exists(이란/Noun)': False,
#   'exists(끌/Noun)': False,
#   'exists(이끌다/Verb)': False,
#   'exists(여성/Noun)': False,
#   'exists(흘러가다/Verb)': False,
#   'exists(로/Noun)': False,
#   'exists(가슴/Noun)': False,
#   'exists(시도/Noun)': False,
#   'exists(만으로/Josa)': False,
#   'exists(8/Number)': False,
#   'exists(표/Noun)': False,
#   'exists(한국인/Noun)': False,
#   'exists(비슷하다/Adjective)': False,
#   'exists(추천/Noun)': False,
#   'exists(OST/Alpha)': False,
#   'exists(간만/Noun)': False,
#   'exists(무엇/Noun)': False,
#   'exists(21/Number)': False,
#   'exists(러브/Noun)': False,
#   'exists(불륜/Noun)': False,
#   'exists(올해/Noun)': False,
#   'exists(느리다/Adjective)': False,
#   'exists(주성치/Noun)': False,
#   'exists(이유/Noun)': False,
#   'exists(영/Noun)': False,
#   'exists(아무리/Adverb)': False,
#   'exists(병맛/Noun)': False,
#   'exists(대해/Noun)': False,
#   'exists(로는/Josa)': False,
#   'exists(-/Punctuation)': False,
#   'exists(네/Determiner)': False,
#   'exists(죄/Noun)': False,
#   'exists(간다/Noun)': False,
#   'exists(얻다/Verb)': False,
#   'exists(치다/Verb)': False,
#   'exists(지우다/Verb)': False,
#   'exists(흘리다/Verb)': False,
#   'exists(싫다/Adjective)': False,
#   'exists(돌아오다/Verb)': False,
#   'exists(회/Noun)': False,
#   'exists(덥다/Adjective)': False,
#   'exists(거지/Noun)': False,
#   'exists(그/Determiner)': False,
#   'exists(길/Noun)': False,
#   'exists(단연/Noun)': False,
#   'exists(예상/Noun)': False,
#   'exists(지만/Josa)': False,
#   'exists(빛나다/Verb)': False,
#   'exists(낫다/Noun)': False,
#   'exists(비다/Verb)': False,
#   'exists(곳/Noun)': False,
#   'exists(끄다/Verb)': False,
#   'exists(문화/Noun)': False,
#   'exists(갖추다/Verb)': False,
#   'exists(죠/Josa)': False,
#   'exists(라니/Josa)': False,
#   'exists(이여/Josa)': False,
#   'exists(까다/Verb)': False,
#   'exists(날리다/Verb)': False,
#   'exists(귀엽다/Adjective)': False,
#   'exists(그것/Noun)': False,
#   'exists(미가/Noun)': False,
#   'exists(성인/Noun)': False,
#   'exists(이어지다/Verb)': False,
#   'exists(해서/Josa)': False,
#   'exists(작가/Noun)': False,
#   'exists(인정/Noun)': False,
#   'exists(흥미롭다/Adjective)': False,
#   'exists(80/Number)': False,
#   'exists(도/Josa)': False,
#   'exists(줌/Noun)': False,
#   'exists(웃기다/Verb)': False,
#   'exists(해지/Noun)': False,
#   'exists(철학/Noun)': False,
#   'exists(북한/Noun)': False,
#   'exists(라/Josa)': False,
#   'exists(?/Punctuation)': False,
#   'exists(보고/Noun)': False,
#   'exists(훈훈하다/Adjective)': False,
#   'exists(몸/Noun)': False,
#   'exists(일/Noun)': False,
#   'exists(이/Noun)': False,
#   'exists(워/Noun)': False,
#   'exists(잊혀지다/Verb)': False,
#   'exists(아픔/Noun)': False,
#   'exists(조/Noun)': False,
#   'exists(귀/Noun)': False,
#   'exists(아직까지/Noun)': False,
#   'exists(똥/Noun)': False,
#   'exists(따다/Verb)': False,
#   'exists(수작/Noun)': False,
#   'exists(게다가/Noun)': False,
#   'exists(원래/Noun)': False,
#   'exists(불/Noun)': False,
#   'exists(성/Suffix)': False,
#   'exists(펑펑/Noun)': False,
#   'exists(잘되다/Verb)': False,
#   'exists(잼/Noun)': False,
#   'exists(웃음/Noun)': False,
#   'exists(암튼/Adverb)': False,
#   'exists(가지다/Verb)': False,
#   'exists(부족/Noun)': False,
#   'exists(스런/Josa)': False,
#   'exists(근데/Adverb)': False,
#   'exists(몰입도/Noun)': False,
#   'exists(담다/Verb)': False,
#   'exists(소름/Noun)': False,
#   'exists(시사회/Noun)': False,
#   'exists(존나/Noun)': False,
#   'exists(세계/Noun)': False,
#   'exists(놀라다/Verb)': False,
#   'exists(만화/Noun)': False,
#   'exists(친구/Noun)': False,
#   'exists(무/Noun)': False,
#   'exists(프로/Noun)': False,
#   'exists(맥/Noun)': False,
#   'exists(이래/Josa)': False,
#   'exists(라지/Noun)': False,
#   'exists(마/Noun)': False,
#   'exists(고맙다/Adjective)': False,
#   'exists(덜/Noun)': False,
#   'exists(몰다/Verb)': False,
#   'exists(각본/Noun)': False,
#   'exists(걍/Adverb)': False,
#   'exists(ost/Alpha)': False,
#   'exists(이하/Noun)': False,
#   'exists(확/Noun)': False,
#   'exists(먼저/Noun)': False,
#   'exists(이/Josa)': False,
#   'exists(토/Noun)': False,
#   'exists(최고다/Noun)': False,
#   'exists(아름답다/Adjective)': False,
#   'exists(번째/Suffix)': False,
#   'exists(께/Josa)': False,
#   'exists(해주다/Verb)': False,
#   'exists(바라보다/Verb)': False,
#   'exists(들이다/Verb)': False,
#   'exists(다니다/Verb)': False,
#   'exists(효/Noun)': False,
#   'exists(개판/Noun)': False,
#   'exists(촬영/Noun)': False,
#   'exists(오빠/Suffix)': False,
#   'exists(돋보이다/Verb)': False,
#   'exists(명품/Noun)': False,
#   'exists(포인트/Noun)': False,
#   'exists(가끔/Noun)': False,
#   'exists(갖다/Verb)': False,
#   'exists(이며/Josa)': False,
#   'exists(초딩/Noun)': False,
#   'exists(에서도/Josa)': False,
#   'exists(까진/Josa)': False,
#   'exists(꽝/Noun)': False,
#   'exists(대화/Noun)': False,
#   'exists(우정/Noun)': False,
#   'exists(이제야/Noun)': False,
#   'exists(환상/Noun)': False,
#   'exists(밖에/Josa)': False,
#   'exists(만/Noun)': False,
#   'exists(현재/Noun)': False,
#   'exists(관계/Noun)': False,
#   'exists(명작/Noun)': False,
#   'exists(만들어지다/Verb)': False,
#   'exists(주말/Noun)': False,
#   'exists(부/Noun)': False,
#   'exists(그러나/Conjunction)': False,
#   'exists(까지도/Josa)': False,
#   'exists(갈다/Verb)': False,
#   'exists(로/Josa)': False,
#   'exists(그/Noun)': False,
#   'exists(병/Noun)': False,
#   'exists(강렬하다/Adjective)': False,
#   'exists(사진/Noun)': False,
#   'exists(뭐라다/Verb)': False,
#   'exists(시리즈/Noun)': False,
#   'exists(꿀잼/Noun)': False,
#   'exists(향/Noun)': False,
#   'exists(자신/Noun)': False,
#   'exists(아/Exclamation)': True,
#   'exists(섬세/Noun)': False,
#   'exists(형편/Noun)': False,
#   'exists(보아/Noun)': False,
#   'exists(태어나다/Verb)': False,
#   'exists(공부/Noun)': False,
#   'exists(깊이/Noun)': False,
#   'exists(성도/Noun)': False,
#   'exists(민망/Noun)': False,
#   'exists(음악/Noun)': False,
#   'exists(좋아하다/Adjective)': False,
#   'exists(ㅡㅡ/KoreanParticle)': False,
#   'exists(부끄럽다/Adjective)': False,
#   'exists(ㅠ/KoreanParticle)': False,
#   'exists(사건/Noun)': False,
#   'exists(뿐이다/Adjective)': False,
#   'exists(냐/Josa)': False,
#   'exists(지/Josa)': False,
#   'exists(해도/Noun)': False,
#   'exists(특히/Adverb)': False,
#   'exists(아이돌/Noun)': False,
#   'exists(해도/Josa)': False,
#   'exists(변하다/Adjective)': False,
#   'exists(지키다/Verb)': False,
#   'exists(실제/Noun)': False,
#   'exists(양심/Noun)': False,
#   'exists(원/Noun)': False,
#   'exists(이제/Noun)': False,
#   'exists(씩/Suffix)': False,
#   'exists(유머/Noun)': False,
#   'exists(본적/Noun)': False,
#   'exists(일상/Noun)': False,
#   'exists(여/Noun)': False,
#   'exists(은/Noun)': False,
#   'exists(대한/Noun)': False,
#   'exists(썩다/Verb)': False,
#   'exists(의심/Noun)': False,
#   'exists(터지다/Verb)': False,
#   'exists(딱하다/Adjective)': False,
#   'exists(살아가다/Verb)': False,
#   'exists(도안/Noun)': False,
#   'exists(건가/Noun)': False,
#   'exists(비극/Noun)': False,
#   'exists(아버지/Noun)': False,
#   'exists(그나마/Adverb)': False,
#   'exists(짝퉁/Noun)': False,
#   'exists(ㅎㅎ/KoreanParticle)': False,
#   'exists(갑/Noun)': False,
#   'exists(값/Noun)': False,
#   'exists(형님/Noun)': False,
#   'exists(낮다/Adjective)': False,
#   'exists(극/NounPrefix)': False,
#   'exists(특유/Noun)': False,
#   'exists(20/Number)': False,
#   'exists(없다/Adjective)': False,
#   'exists(생각/Noun)': False,
#   'exists(외계인/Noun)': False,
#   'exists(첫/Noun)': False,
#   'exists(남다/Verb)': False,
#   'exists(세다/Verb)': False,
#   'exists(이든/Josa)': False,
#   'exists(공포물/Noun)': False,
#   'exists(</Punctuation)': False,
#   'exists(만나다/Verb)': False,
#   'exists(..?/Punctuation)': False,
#   'exists(제작비/Noun)': False,
#   'exists(평가/Noun)': False,
#   'exists(드럽/Noun)': False,
#   'exists(희생/Noun)': False,
#   'exists(안다/Verb)': False,
#   'exists(길다/Adjective)': False,
#   'exists(영국/Noun)': False,
#   'exists(이니/Josa)': False,
#   'exists(분노/Noun)': False,
#   'exists(시선/Noun)': False,
#   'exists(그럭저럭/Noun)': False,
#   'exists(결정/Noun)': False,
#   'exists(눈빛/Noun)': False,
#   'exists(역겹다/Adjective)': False,
#   'exists(어린이/Noun)': False,
#   'exists(캐/Noun)': False,
#   'exists(감동/Noun)': False,
#   'exists(???/Punctuation)': False,
#   'exists(들다/Verb)': False,
#   'exists(따로/Adverb)': False,
#   'exists(통쾌/Noun)': False,
#   'exists(제작/Noun)': False,
#   'exists(더/Noun)': False,
#   'exists(네/Noun)': False,
#   'exists(세월/Noun)': False,
#   'exists(의리/Noun)': False,
#   'exists(극/Suffix)': False,
#   'exists(로서/Noun)': False,
#   'exists(ㅅ/KoreanParticle)': False,
#   'exists(끝나다/Verb)': False,
#   'exists(빛/Noun)': False,
#   'exists(틀다/Verb)': False,
#   'exists(겁니다/Verb)': False,
#   'exists(처/Noun)': False,
#   'exists(살/Noun)': False,
#   'exists(삼/Noun)': False,
#   'exists(흑인/Noun)': False,
#   'exists(명/Noun)': False,
#   'exists(허다/Verb)': False,
#   'exists(예쁘다/Adjective)': False,
#   'exists(메시지/Noun)': False,
#   'exists(조합/Noun)': False,
#   'exists(않다/Verb)': False,
#   'exists(변태/Noun)': False,
#   'exists(따뜻하다/Adjective)': False,
#   'exists(어색하다/Adjective)': False,
#   'exists(주/Noun)': False,
#   'exists(겨우/Noun)': False,
#   'exists(과거/Noun)': False,
#   'exists(채널/Noun)': False,
#   'exists(답답하다/Adjective)': False,
#   'exists(떼다/Verb)': False,
#   'exists(이번/Noun)': False,
#   'exists(몇/Noun)': False,
#   'exists(끝내다/Verb)': False,
#   'exists(와의/Josa)': False,
#   'exists(작다/Adjective)': False,
#   'exists(안타깝다/Adjective)': False,
#   'exists(보라/Noun)': False,
#   'exists(아저씨/Noun)': False,
#   'exists(소소하다/Adjective)': False,
#   'exists(정말로/Adverb)': False,
#   'exists(영화/Noun)': False,
#   'exists(성하/Noun)': False,
#   'exists(난/Josa)': False,
#   'exists(차이/Noun)': False,
#   'exists(특이하다/Adjective)': False,
#   'exists(투자/Noun)': False,
#   'exists(러닝/Noun)': False,
#   'exists(동생/Noun)': False,
#   'exists(대하다/Verb)': False,
#   'exists(맘/Noun)': False,
#   'exists(어처구니/Noun)': False,
#   'exists(놈/Noun)': False,
#   'exists(암/Noun)': False,
#   'exists(뭐임/Noun)': False,
#   'exists(놓치다/Verb)': False,
#   'exists(함/Noun)': False,
#   'exists(그린/Noun)': False,
#   'exists(2/Number)': False,
#   'exists(것/Noun)': False,
#   'exists(코/Noun)': False,
#   'exists(한테/Josa)': False,
#   'exists(수준/Noun)': False,
#   'exists(날다/Verb)': False,
#   'exists(자체/Noun)': False,
#   'exists(데리/Noun)': False,
#   'exists(부모님/Noun)': False,
#   'exists(설마/Noun)': False,
#   'exists(는걸/Noun)': False,
#   'exists(편견/Noun)': False,
#   'exists(말/Noun)': False,
#   'exists(낚였/Noun)': False,
#   'exists(게임/Noun)': False,
#   'exists(글/Noun)': False,
#   'exists(생생/Noun)': False,
#   'exists(표현/Noun)': False,
#   'exists(햇/Noun)': False,
#   'exists(미드/Noun)': False,
#   'exists(떠나다/Verb)': False,
#   'exists(진정/Noun)': False,
#   'exists(행동/Noun)': False,
#   'exists(기회/Noun)': False,
#   'exists(티비/Noun)': False,
#   'exists(쓸다/Verb)': False,
#   'exists(옛날/Noun)': False,
#   'exists(♥/Foreign)': False,
#   'exists(//Punctuation)': False,
#   'exists(희망/Noun)': False,
#   'exists(중반/Noun)': False,
#   'exists(완전/Noun)': False,
#   'exists(대작/Noun)': False,
#   'exists(들/Suffix)': False,
#   'exists(연출/Noun)': False,
#   'exists(>/Punctuation)': False,
#   'exists(삶/Noun)': False,
#   'exists(그래도/Adverb)': False,
#   'exists(에나/Josa)': False,
#   'exists(으로도/Josa)': False,
#   'exists(반복/Noun)': False,
#   'exists(스/Noun)': False,
#   'exists(때/Noun)': False,
#   'exists(완벽하다/Adjective)': False,
#   'exists(님/Suffix)': False,
#   'exists(자극/Noun)': False,
#   'exists(등장인물/Noun)': False,
#   'exists(대가/Noun)': False,
#   'exists(일어나다/Verb)': False,
#   'exists(이랑/Josa)': False,
#   'exists(b/Alpha)': False,
#   'exists(거슬리다/Adjective)': False,
#   'exists(수도/Noun)': False,
#   'exists(재다/Verb)': False,
#   'exists(정치/Noun)': False,
#   'exists(영화인/Noun)': False,
#   'exists(사이/Noun)': False,
#   'exists(으/Adverb)': False,
#   'exists(심심하다/Adjective)': False,
#   'exists(한번/Noun)': False,
#   'exists(생활/Noun)': False,
#   'exists(일품/Noun)': False,
#   'exists(엇/VerbPrefix)': False,
#   'exists(함께/Adverb)': False,
#   'exists(상/Suffix)': False,
#   'exists(딸/Noun)': False,
#   'exists(좀/Noun)': False,
#   'exists(지난/Noun)': False,
#   'exists(싸다/Verb)': False,
#   'exists(./Punctuation)': False,
#   'exists(솔직하다/Adjective)': False,
#   'exists(풋풋/Noun)': False,
#   'exists(졸다/Verb)': False,
#   'exists(글쎄/Noun)': False,
#   'exists(호구/Noun)': False,
#   'exists(라이/Noun)': False,
#   'exists(볼때/Noun)': False,
#   'exists(지는/Josa)': False,
#   'exists(보다는/Josa)': False,
#   'exists(씨/Suffix)': False,
#   'exists(만큼/Noun)': False,
#   'exists(돋다/Adjective)': False,
#   'exists(준/Noun)': False,
#   'exists(라인/Noun)': False,
#   'exists(따라가다/Verb)': False,
#   'exists(심각하다/Adjective)': False,
#   'exists(잠/Noun)': False,
#   'exists(바로/Noun)': False,
#   'exists(쓰레기/Noun)': False,
#   'exists(와우/Noun)': False,
#   'exists(피해자/Noun)': False,
#   'exists(아련하다/Adjective)': False,
#   'exists(관/Noun)': False,
#   'exists(우/Adverb)': False,
#   'exists(요즘/Noun)': False,
#   'exists(ㅇㅇ/KoreanParticle)': False,
#   'exists(선물/Noun)': False,
#   'exists(드리다/Verb)': False,
#   'exists(여행/Noun)': False,
#   'exists(네/Josa)': False,
#   'exists(젊다/Adjective)': False,
#   'exists(못/Noun)': False,
#   'exists(자/Suffix)': False,
#   'exists(뛰어나다/Adjective)': False,
#   'exists(난/Noun)': False,
#   'exists(열정/Noun)': False,
#   'exists(허무/Noun)': False,
#   'exists(느낌/Noun)': False,
#   'exists(대사/Noun)': False,
#   'exists(짓/Noun)': False,
#   'exists(찍다/Verb)': False,
#   'exists(얼굴/Noun)': False,
#   'exists(틀리다/Verb)': False,
#   'exists(동물/Noun)': False,
#   'exists(대의/Noun)': False,
#   'exists(잠깐/Noun)': False,
#   'exists(한국영/Noun)': False,
#   'exists(초등학생/Noun)': False,
#   'exists(역사/Noun)': False,
#   'exists(망작/Noun)': False,
#   'exists(조절/Noun)': False,
#   'exists(에는/Josa)': False,
#   'exists(마무리/Noun)': False,
#   'exists(이미/Adverb)': False,
#   'exists(년/Noun)': False,
#   'exists(동화/Noun)': False,
#   'exists(매우/Noun)': False,
#   'exists(남편/Noun)': False,
#   'exists(화/Noun)': False,
#   'exists(라고/Josa)': False,
#   'exists(......./Punctuation)': False,
#   'exists(커플/Noun)': False,
#   'exists(류/Noun)': False,
#   'exists(밑/Noun)': False,
#   'exists(제/Noun)': False,
#   'exists(연예인/Noun)': False,
#   'exists(보이다/Verb)': False,
#   'exists(살아나다/Verb)': False,
#   'exists(히어로/Noun)': False,
#   'exists(쏘다/Verb)': False,
#   'exists(감/Noun)': False,
#   'exists(본영/Noun)': False,
#   'exists(흥미진진/Noun)': False,
#   'exists(쯤/Suffix)': False,
#   'exists(7/Number)': False,
#   'exists(아침/Noun)': False,
#   'exists((?)/Punctuation)': False,
#   'exists(웬만하다/Adjective)': False,
#   'exists(대체/Noun)': False,
#   'exists(이야/Josa)': False,
#   'exists(낫다/Verb)': False,
#   'exists(전혀/Noun)': False,
#   'exists(싸우다/Verb)': False,
#   'exists(감상/Noun)': False,
#   'exists(속편/Noun)': False,
#   'exists(싶다/Verb)': False,
#   'exists(후/Noun)': False,
#   'exists(무협/Noun)': False,
#   'exists(기술/Noun)': False,
#   'exists(줄/Noun)': False,
#   'exists(배우/Noun)': False,
#   'exists(너/Noun)': False,
#   'exists(어른/Noun)': False,
#   'exists(점/Noun)': False,
#   'exists(내생/Noun)': False,
#   'exists(맞추다/Verb)': False,
#   'exists(나중/Noun)': False,
#   'exists(로만/Noun)': False,
#   'exists(분/Noun)': False,
#   'exists(던지다/Verb)': False,
#   'exists(저런/Noun)': False,
#   'exists(잘못/Noun)': False,
#   'exists(ㄷㄷ/KoreanParticle)': False,
#   'exists(시기/Noun)': False,
#   'exists(걸/Noun)': False,
#   'exists(질/Noun)': False,
#   'exists(취향/Noun)': False,
#   'exists(해/Noun)': False,
#   'exists(변화/Noun)': False,
#   'exists(마음/Noun)': False,
#   'exists(지루/Noun)': False,
#   'exists(설명/Noun)': False,
#   'exists(깊다/Adjective)': False,
#   'exists(마다/Josa)': False,
#   'exists(계속/Noun)': False,
#   'exists(당시/Noun)': False,
#   'exists(맨/Noun)': False,
#   'exists(시시/Noun)': False,
#   'exists(복수/Noun)': False,
#   'exists(거/Noun)': False,
#   'exists(처음/Noun)': False,
#   'exists(70/Number)': False,
#   'exists(놓다/Verb)': False,
#   'exists(전쟁/Noun)': False,
#   'exists(못/VerbPrefix)': False,
#   'exists(얼마/Noun)': False,
#   'exists(전작/Noun)': False,
#   'exists("""/Punctuation)': False,
#   'exists(티/Noun)': False,
#   'exists(의외로/Adverb)': False,
#   'exists(답/Noun)': False,
#   'exists(국내/Noun)': False,
#   'exists(댓글/Noun)': False,
#   'exists(극장판/Noun)': False,
#   'exists(많이/Adverb)': False,
#   'exists(니까/Josa)': False,
#   'exists(고민/Noun)': False,
#   'exists(아쉬움/Noun)': False,
#   'exists(년도/Noun)': False,
#   'exists(억지로/Noun)': False,
#   'exists(불가/Noun)': False,
#   'exists(예요/Josa)': False,
#   'exists(그래서/Adverb)': False,
#   'exists(편집/Noun)': False,
#   'exists(좋아지다/Adjective)': False,
#   'exists(밉다/Adjective)': False,
#   'exists(력/Suffix)': False,
#   'exists(괴물/Noun)': False,
#   'exists(탄탄/Noun)': False,
#   'exists(재밌다/Adjective)': False,
#   'exists(엉망/Noun)': False,
#   'exists(../Punctuation)': True,
#   'exists(롭고/Josa)': False,
#   'exists(뛰어넘다/Verb)': False,
#   'exists(강추/Noun)': False,
#   'exists(대/Suffix)': False,
#   'exists(조용하다/Adjective)': False,
#   'exists(전개/Noun)': False,
#   'exists(해내다/Verb)': False,
#   'exists(등등/Noun)': False,
#   'exists(빌리다/Verb)': False,
#   'exists(조차/Josa)': False,
#   'exists(라서/Josa)': False,
#   'exists(여주/Noun)': False,
#   'exists(랄/Noun)': False,
#   'exists(대로/Josa)': False,
#   'exists(예/Noun)': False,
#   'exists(연기력/Noun)': False,
#   'exists(자살/Noun)': False,
#   'exists(독특하다/Adjective)': False,
#   'exists(오그/Noun)': False,
#   'exists(볼/Noun)': False,
#   'exists(허세/Noun)': False,
#   'exists(모/Noun)': False,
#   'exists(그렇게/Adverb)': False,
#   'exists(낚/Noun)': False,
#   'exists(늘/Noun)': False,
#   'exists(단지/Noun)': False,
#   'exists(귀신/Noun)': False,
#   'exists(참고/Noun)': False,
#   'exists(정체/Noun)': False,
#   'exists(채/Noun)': False,
#   'exists(SF/Alpha)': False,
#   'exists(여서/Josa)': False,
#   'exists(15/Number)': False,
#   'exists(사수/Noun)': False,
#   'exists(일본/Noun)': False,
#   'exists(느와르/Noun)': False,
#   'exists(사/Noun)': False,
#   'exists(이리/Adverb)': False,
#   'exists(심하다/Adjective)': False,
#   'exists(멀다/Adjective)': False,
#   'exists(움/Noun)': False,
#   'exists(재미없다/Adjective)': False,
#   'exists(주기도/Noun)': False,
#   'exists(멍청하다/Adjective)': False,
#   'exists(견자단/Noun)': False,
#   'exists(선택/Noun)': False,
#   'exists(한마디/Noun)': False,
#   'exists(비주/Noun)': False,
#   'exists(감성/Noun)': False,
#   'exists(때리다/Verb)': False,
#   'exists(끼다/Verb)': False,
#   'exists(????/Punctuation)': False,
#   'exists(막/Noun)': False,
#   'exists(관심/Noun)': False,
#   'exists(....../Punctuation)': False,
#   'exists(헐리웃/Noun)': False,
#   'exists(채우다/Verb)': False,
#   'exists(막장드라마/Noun)': False,
#   'exists(웃다/Verb)': False,
#   'exists(꾸다/Verb)': False,
#   'exists(잇다/Verb)': False,
#   'exists(주의/Noun)': False,
#   'exists(깔끔하다/Adjective)': False,
#   'exists(머리/Noun)': False,
#   'exists(감사/Noun)': False,
#   'exists(살인/Noun)': False,
#   'exists(꿈/Noun)': False,
#   'exists(멋지다/Adjective)': False,
#   'exists(뽑다/Verb)': False,
#   'exists(유쾌하/Noun)': False,
#   'exists(주인공/Noun)': False,
#   'exists()/Punctuation)': False,
#   'exists(듬/Noun)': False,
#   'exists(적/Noun)': False,
#   'exists(밀리다/Verb)': False,
#   'exists(간/Suffix)': False,
#   'exists(카메라/Noun)': False,
#   'exists(또/Noun)': False,
#   'exists(범죄/Noun)': False,
#   'exists(개/Suffix)': False,
#   'exists(말고/Josa)': False,
#   'exists(굿굿/Noun)': False,
#   'exists(아프다/Adjective)': False,
#   'exists(식상하다/Adjective)': False,
#   'exists(가깝다/Adjective)': False,
#   'exists(등장/Noun)': False,
#   'exists(지다/Verb)': False,
#   'exists(코난/Noun)': False,
#   'exists(ㅜ/KoreanParticle)': False,
#   'exists(흔하다/Adjective)': False,
#   'exists(홍보/Noun)': False,
#   'exists(의도/Noun)': False,
#   'exists(깨다/Verb)': False,
#   'exists(이라고/Josa)': False,
#   'exists(번/Noun)': False,
#   'exists(엄마/Noun)': False,
#   'exists(본방/Noun)': False,
#   'exists(오빠/Noun)': False,
#   'exists(노출/Noun)': False,
#   'exists(크리스마스/Noun)': False,
#   'exists(순간/Noun)': False,
#   'exists(내내/Noun)': False,
#   'exists(나머지/Noun)': False,
#   'exists(ㅡ/KoreanParticle)': False,
#   'exists(극장/Noun)': False,
#   'exists(돌다/Verb)': False,
#   'exists(시작/Noun)': False,
#   'exists(홍콩/Noun)': False,
#   'exists(만큼은/Josa)': False,
#   'exists(받다/Verb)': False,
#   'exists(아줌마/Noun)': False,
#   'exists(끝/Noun)': False,
#   'exists(한/Determiner)': False,
#   'exists(갑자기/Noun)': False,
#   'exists(쓰다/Verb)': False,
#   'exists(싸구려/Noun)': False,
#   'exists(스케일/Noun)': False,
#   'exists(베스트/Noun)': False,
#   'exists(...?/Punctuation)': False,
#   'exists(무척/Noun)': False,
#   'exists(랑/Josa)': False,
#   'exists(""""/Punctuation)': False,
#   'exists(후회/Noun)': False,
#   'exists(안/Noun)': False,
#   'exists(~~/Punctuation)': False,
#   'exists(+/Punctuation)': False,
#   'exists(바뀌다/Verb)': False,
#   'exists(공포영화/Noun)': False,
#   'exists(되다/Verb)': False,
#   'exists(노잼/Noun)': False,
#   'exists(미래/Noun)': False,
#   ...},
#  '0')

# %%
import konlpy
import gensim
from pprint import pprint

# %%
def read_data(filename):
    with open(filename, 'r') as f:
        data = [line.split('\t') for line in f.read().splitlines()]
        data = data[1:]   # header 제외
    return data
train_data = read_data('ratings_train.txt')
test_data = read_data('ratings_test.txt')

# %%
from konlpy.tag import Twitter
pos_tagger = Twitter()

# %%
def tokenize(doc):
    # norm, stem은 optional
    return ['/'.join(t) for t in pos_tagger.pos(doc, norm=True, stem=True)]

# %%
train_docs = [(tokenize(row[1]), row[2]) for row in train_data]
test_docs = [(tokenize(row[1]), row[2]) for row in test_data]

# %%
all_docs = []

for doc in train_docs:
    all_docs.append(doc[0])
    
for doc in test_docs:
    all_docs.append(doc[0])

print(len(all_docs))
# Out:
# 200000

# %%
dics = gensim.corpora.Dictionary(all_docs)

# %%
dics

# %%
from gensim import models

tf_ko = []

for _ in range(len(all_docs)):
    tf_ko.append(dics.doc2bow(all_docs.pop(0)))

# %%
tf_ko[41831]
# Out:
# [(37, 1), (624, 1), (1067, 1), (1308, 1)]

# %%
len(tf_ko)
# Out:
# 200000
